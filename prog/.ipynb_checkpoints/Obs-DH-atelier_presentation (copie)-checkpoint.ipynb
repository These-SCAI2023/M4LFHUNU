# %% [markdown]
# <table>
#     <tr>
#     <td style="text-align:center"><h1> Atelier Digit_Hum 2023 </h1>
#         <h3>"Manipuler des données en SHS : R, Python et les carnets interactifs" </h3>
#
#    <h2>Garder trace de son travail et le partager en traitement automatique des langues </h2>
#     <h3><br>Caroline Koudoro-Parfait(1,2,3),</h3>
#         <h3>caroline.parfait@sorbonne-universite.fr</h3>
#         1) OBTIC, Sorbonne Université, Paris, France<br>
# (2) STIH, Sorbonne Université, Paris, France<br>
# (3) SCAI, Sorbonne Center for Artificial Intelligence, Paris, France<br>
#     </td>
# </table>
# <table>
#      <td style="text-align:center"><img src="../DATA/images/github.png" width="15" height="7"></td>
# <td style="text-align:center">Github :<a href="https://github.com/obtic-sorbonne/Toolbox-site/tree/nermap">https://github.com/obtic-sorbonne/Toolbox-site/tree/nermap</a>  </td>
# </table>
# <table>
#     <td style="text-align:center"><img src="../DATA/images/ObTIC-logo-blue.png" width="100" height="50"></td>
#     <td style="text-align:center"><img src="../DATA/images/scai_su_logo_large.png" width="100" height="50"></td>
#     <td style="text-align:center"><img src="../DATA/images/STIH.png" width="100" height="50"></td>
# </table>
#
#
# -----
#
# -----

# %% [markdown]
# # Angle expérimental : Impact de la reconnaissance optique de caractères (OCR) sur la reconnaissance d'entités nommées (REN)

# %% [markdown]
# ## Les données d'entrée : difficultés pour l'OCR
# <table>
#     <tr>
#     <td style="text-align:center"><img src="../DATA/images/CARRAUD_IMAGES.png" width="300" height="150"></td>
#     <td style="text-align:center"><img src="../DATA/images/BALZAC_PDF.png" width="300" height="150"></td>
#     </tr>
#      <tr>
#     <td style="text-align:center"><h3>Illustrations</h3></td>
#          <td style="text-align:center"><h3>double colonnes</h3></td>
#     </tr>
# </table>

# %% [markdown]
# ## Textes sur deux colonnes
#
# <h3>Vert : colonne de droite</h3>
# <br>
# <img src="../DATA/images/balzac.png">

# %% [markdown]
# ## L'épineuse question de la correction automatique
#
# Évaluation de la librairie **jamspell** : https://github.com/bakwc/JamSpell
#
#
# <img src="../DATA/images/correction_automatique.png">
#
#  - **MOBC** - mal océrisées bien corrigées ;
#  - **MOMC** - mal océrisées mal corrigées ;
#  - **MOI** - mal océrisées ignorées ;
#  - **BOIC** - bien océrisées indûment corrigées.

# %% [markdown]
# # Élaboration de la chaine de traitement Epiméthée : de l'OCR à la carte
#
# *Épiméthée est une chaîne de traitement qui permet de bout-en-bout d'extraire les entités nommées (EN) de lieu dans un texte (numérisé ou non), puis de récupérer leurs coordonnées géographiques (Geopy) afin de les cartographier. Pour aider l'utilisateur à mieux filtrer la sortie qui peut être bruitée nous proposons une étape de clusterisation des EN.*

# %% [markdown]
# ### 1. La chaine de traitement
#
# ### 2. Les différentes étapes de développement
#
# ### 3. Interface d'Épiméthée

# %% [markdown]
# ## Schéma de la chaine de traitement
#
# <img src="../DATA/images/epimethee_workflow.png">

# %%
import spacy
import glob
import pandas as pd

# %%
#La fonction qui sert à lire les textes pour tous le notebook. 
#Attention si vous souhaitez lire un autre format de fichier :csv, json, etc., elle n'est pas adéquate
def read_text(path_corpora):
        with open (path_corpora, "r", encoding="utf-8") as fichier:
            txt=fichier.read()
        return txt
    

path_corpus= "../DATA/ELTeCFRA/ADAM/*/*.txt"
for path in glob.glob(path_corpus):
    nom_fichier=path.split("/")[-1]
    texte=read_text(path)
    print(f"_________Titre du texte lu : {nom_fichier}__________")
    print("\n")
    print(f"Le texte lu :\n\n\n {texte[:250]}")
    print("\n")
# Out:
# _________Titre du texte lu : ADAM_Mon-village_TesseractFra-PNG.txt__________
#
#
# Le texte lu :
#
#
#  —-— Chez vous, curé! c’est impardonnable.
# Vous quitterez la commune!
#
# ,— Ce pauvre curé de Morlincourt! dit un
# chacun, si parlant, si brave homme! On ne
# sait pas; peut—être bien qu’au lieu d’un mau—
# vais curé il eût fait un bon mari.
#
# -À— Des histoir
#
#
# _________Titre du texte lu : ADAM_Mon-village_REF.txt__________
#
#
# Le texte lu :
#
#
#  — Chez vous, curé ! c'est impardonnable. Vous quitterez la commune !
# — Ce pauvre curé de Morlincourt ! dit un chacun, si parlant, si brave homme ! On ne sait pas ; peut-être bien qu'au lieu d'un mauvais curé il eût fait un bon mari.
# — Des histoires
#
#
# _________Titre du texte lu : ADAM_Mon-village_Kraken-base.txt__________
#
#
# Le texte lu :
#
#
#  - Chez vous, curel c'est impardonnable.
# Vous quitterez la communel
# - Ce pauvre cure de Mlorlincourtl dit un
# chacun, si parlant, si brave hommel On ne
# sait pas; peut-etre bien qu'au lieu d'un mau-
# vais cure il eit fait un bon mari.
# - Des histoires de

# %% [markdown]
# ## Reconnaissance d'entités nommées (REN) sur des données bruitées avec spaCy
#
# https://spacy.io/
#
# SpaCy est un outil de traitement automatique des langues qui peut également être utilisé pour la REN.
#
# Il permet de retrouver les EN accompagnées d'un libellé, ainsi que la position du caractère de début et de fin du terme identifié.
#
# Nom de lieu : LOC ;
# Nom de la personne : PERS ;
# Organisations : ORG ; ...

# %%
# chargement du modèle de langue de spaCy avec lequel vous souhaitez travailler
#Vous pouvez changer le modèle de langue : 0="fr_core_news_lg", 1="fr_core_news_md", 2="fr_core_news_sm"

modele_langfr=["fr_core_news_lg","fr_core_news_md","fr_core_news_sm"]
modele=modele_langfr[0] 
nlp = spacy.load(modele)

# %% [markdown]
# ## displaCy :  Visualisation des sorties bruitées de REN
# https://demos.explosion.ai/displacy-ent
#
# **Vous devez arrêter le programme pour pouvoir passer à l'affichage suivant.**
#
#
# <h3>--> Displacy permet d'afficher les EN récupérées par spaCY mais pas de les stocker dans un format de données réutilisables</h3>
#
#
# Légende :
#  - "REF": texte de reference
#
#  - "Kraken": Kraken modèle de base
#
#  - "Tesseract": Tesseract modèle adapté à la langue du corpus

# %% [markdown]
# ## Arborescence de fichier
# <img src="../DATA/images/arborescence.png">

# %%
# Importer le visualiseur Displacy de Spacy
from spacy import displacy

#cette boucle permet la lecture, l'analyse et l'affichage pour les différentes versions du texte
for path in glob.glob(path_corpus):
    version=path.split("/")[3]
    name_version=version.split("_")[-1]
    text=read_text(path)
    
    if "REF" in path:
        print("Reference text output :" )
        doc1 =  nlp(text[:2000])
        
    if "Kraken" in path:
        doc2 =  nlp(text[:2000])
        
    if "Tesseract" in path:
        doc3 =  nlp(text[:2000])
    
#Afficher les résultats pour la REN avec le visualiser Displacy
disp=displacy.serve(doc1,style="ent")
# Out:
# Reference text output :
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">— Chez vous, curé ! c'est impardonnable. Vous quitterez la commune ! </br>— Ce pauvre curé de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Morlincourt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ! dit un chacun, si parlant, si brave homme ! On ne sait pas ; peut-être bien qu'au lieu d'un mauvais curé il eût fait un bon mari. </br>— Des histoires de curé, il en pleut ! dit le père
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ; mais je penche toujours pour celle de défunt mon grand-oncle : </br>Ne trouva-t-il point un jour défunte ma grand'tante en conversation (pour bien parler devant les bonnets blancs) avec le receveur des dîmes de son village. Il n'y avait guère de justice alors pour un simple berger. En criant fort, défunt mon grand-oncle pouvait arriver à se voir pendu, voilà tout. Il prit donc le parti de faire semblant de rire. Bien mieux, sur place, il commanda à sa femme de cuire des gauffres. Il y a manière de s'arranger. Deux heures après il reportait monsieur le curé dans son lit, furtivement, par la nuit sombre. Or, le lendemain se trouvait être un dimanche.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ! mes camarades, dans le village, les plus bigots se virent forcés de se passer de messe, parce que monsieur le curé était, sauf votre respect, crevé. </br>De profundis ! </br>— De profundis ! répéta
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeacquet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , qui venait d'entrer. Vous parlez d'un curé mort ? Que le bon Dieu ait pitié de son âme ! </br>— Il en a bien besoin d'après ça, dit la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# . </br>— Tu deviens par trop gouailleuse, la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , dit
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeacquet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , tu tourneras mal. </br>— Je vois à mes étoiles qu'il est déjà tard, allons-nous-en, dit le vieux berger. Quant à toi, la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , je souhaite que le mot de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeacquet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ne te porte pas malheur ! </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     II
# LA ROSE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . </br>À force, à force de payer ses galants, « d'écoute s'il pleut » [7] et de les voir accourir tout de même, la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  devenait un brin trop acrimonieuse ; fière comme
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artaban
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , elle s'illusionnait au point de croire qu'elle serait toujours pareillement festoyée. </br>Aussi les garçons, pour la faire endêver, ne trouvaient-ils rien de mieux que de lui parler mariage. M'est avis que ce n'était pas un manque de réflexion qui faisait refuser, à cette jeunesse,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
print("Kraken output : ")
displacy.serve(doc2,style="ent")
# Out:
# Kraken output :
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">- Chez vous,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     curel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  c'est impardonnable.</br>Vous quitterez la communel</br>- Ce pauvre cure de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mlorlincourtl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  dit un</br>chacun, si parlant, si brave hommel On ne</br>sait pas; peut-etre bien qu'au lieu d'un mau-</br>vais cure il
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fait un bon mari.</br>- Des histoires de cure, il en pleutl dit le</br>pere
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ; maisje penche toujours pour celle</br>de dfunt mon grand-oncle:</br>Ne trouva-t-il point un jour defunte ma</br>-----------------e----a---------esssasassaa.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LLL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .., ..g-----</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MO N VILLAGE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</br>grand'tante en conversation (pour bien parler</br>devant les bonnets blancs) avec le receveur</br>des dimes de son village. Il n'y avait guere de</br>justice alors pour un simple berger. En criant</br>fort, defunt mon grand-oncle pouvait arriver</br> se voir pendu,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     voila
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  tout. Il prit donc le</br>parti de faire semblant de rire. Bien mieux,</br>sur place, il commanda a sa femme de cuire</br>des gauffres. Il y a maniere de s'arranger.</br>Deux heures apres il reportait monsieur le</br>cure dans son lit, furtivement, par la nuit</br>sombre. Or, le lendemain se trouvait etre un</br>dimanche. Lasl mes camarades, dans le vil-</br>lage, les plus bigots se virent forces de se</br>passer de messe, parce que monsieur le cure</br>etait, sauf votre respect,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     creve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</br>De profunlis l</br>.- De profundis l repeta Jeacquet, qui
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ve-
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# </br>nait d'entrer. Vous parlez d'un cure mort</br>Que le bon
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dicu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ait pitie de son
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# </br>h</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IIIMON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  VILLAGE.</br>- Il en a bien besoin d'apres
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gca
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , dit la</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</br>-Tu deviens par trop gouailleuse, la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,</br>dit
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeacquet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , tu tourneras mal.</br>- Je vois a mes etoiles qu'il est dejh tard,</br>allons-nous-en, dit le vieux berger. (Quant h</br>toi, la
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , je souhaite que le mot de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeac-
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </br>quet ne te porte pas malheurl</br>-----------LA
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     R0SE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# </br>----LA
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ROSE
#     <span style="font-size: 0.8em; font-weight: bold; line-heigh
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
print("Tesseractfr text output :" )
displacy.serve(doc3,style="ent")
# Out:
# Tesseractfr text output :
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">—-— Chez vous, curé! c’est impardonnable.</br>Vous quitterez la commune!</br></br>,— Ce pauvre curé de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Morlincourt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ! dit un</br>chacun, si parlant, si brave homme! On ne</br>sait pas; peut—être bien qu’au lieu d’un mau—</br>vais curé il eût fait un bon mari.</br></br>-À— Des histoires de curé, il enpleut! dit le</br>père
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ; mais je penche toujours pour celle</br>‘ de défunt mon grand—oncle :</br></br>Ne trouva—t—il point un jour défunte ma</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MST-M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# &quot; 3'2ﬁà—
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JÆ’,F——Er
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# …‘_ vu.… “la—“ «mn,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ._‘
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .._…__…44 - ..</br></br>Ww.</br>. —.-&gt;;</br></br>&amp;</br>:æ</br>lx</br>1.5</br>$&quot;»</br>‘.</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     &amp;
#
# vo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# …——</br>: .—</br></br>-‘3=7 .. .-</br></br>-*m</br></br>...—vo“</br></br>.” ‘=&amp; J-o—</br></br>    </br></br> </br></br>34 MON VILLAGE.</br></br>grand’tante en conversation (pour bien parler</br>devant les bonnets blancs) avec le receveur</br>des dîmes de son village. Il n’y avait guère de</br>justice alors pour un simple berger. En criant</br>fort, défunt mon grand—oncle pouvait arriver</br>à. se voir pendu, voilà tout. Il prit donc le</br>parti de faire semblant de rire. Bien mieux,</br>sur place , il commanda à. sa femme de cuire</br>des gaulfres. Il y a manière de s’arranger.</br>Deux heures après il reportait monsieur le</br>curé dans son lit, furtivement, par la nuit</br>sombre. Or, le lendemain se trouvait être un '</br>dimanche.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ! mes camarades, dans le vil—</br>lage, les plus bigots se virent forcés de se</br>passer de messe, parce que monsieur le curé</br>était, sauf votre respect, crevé.</br></br>De jam/‘unäis !</br></br>.— De profundz‘s ! répéta
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeacquet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , qui ve—</br>nait d’entrer. Vous parlez d’un curé mort?</br></br>Que le bon Dieu ait pitié de son âme!</br></br> </br></br>    </br></br>_ 330N vmmcn._ 35</br>a bien besoin d3après ça, dit la.</br></br> </br></br>___--.... ---…-.--.—-_._... -..-___— ..—. . ,_</br></br>   </br></br>…ù— -u'au—_—……——.-. .——..——..«—</br></br> </br></br> </br></br> </br></br> </br></br> </br></br> </br></br>.… ___-., ...—_.</br></br> </br></br> </br></br> </br></br>&quot;. _' . . &gt;&quot; “n‘ _‘v‘.,</br>‘&quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T.-_.'\
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ,_ &quot;,;___ $,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1- &amp; \r—
#
#
#
# Ïu—._ “ .
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  - {</br></br>LA,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ROSE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</br></br> </br></br>de même, la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Base
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  devenait un brin trop</br>nantaise,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ﬁère co‘ujme‘ A;rtaban
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , elle s ’
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     il—
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>&quot; ;'t au point de croire qu ’elle serait</br>pare1llemeht festoyée. Aussi les gar—=-</br></br> </br></br> </br></br>...-.…-.</br></br>___…__ n-,”‘* , .. ,.</br></br>..- -..—w“… .…”</br>……. ,—.. -—-—v— — _ . — ,</br></br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     I
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </br></br>+0 4 MON “VILLAGE.</br></br>   </br></br>d’aucunes fo</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ## Récupérer les résultats de REN dans plusieurs formats :
#
#  -  sous forme de tableau avec pandas
#  - sous forme de tableau csv
#  - au format json

# %%
import pandas as pd
from IPython.display import display
import json

# %%
#stockage des données dans un format json pour une réutilisation des données
def stocker(chemin, contenu):
    w =open(chemin, "w")
    w.write(json.dumps(contenu , indent = 2))
    w.close()
    # print(chemin)
    
    return chemin

# %%
for path in glob.glob(path_corpus):

    dict_ent={}
    liste_ent=[]
    liste_label=[]
    liste_contxt_droit=[]
    liste_contxt_gauche=[]
    auteur=path.split("/")[3]
    version=path.split("/")[-2]
    version=version.split("_")[-1]
    print("------------",auteur,version)

    
    text=read_text(path)
    #print(f"          \n\n {text}")
    
    doc = nlp(text)

    for ent in doc.ents:
        if ent.label_=="LOC":### Retrieve spacial entities only
            liste_ent.append(ent.text)
            liste_label.append(ent.label_)
            liste_contxt_gauche.append(text[ent.start_char-15:ent.start_char])

            liste_contxt_droit.append(text[ent.end_char:ent.end_char+15])
        
    dict_ent["Entite"]=liste_ent
    dict_ent["Label"]=liste_label
    dict_ent["liste_contxt_gauche"]=liste_contxt_gauche
    dict_ent["liste_contxt_droit"]=liste_contxt_droit
    
    data_tab = pd.DataFrame(dict_ent)
    
    display(data_tab)  
    data_tab.to_csv(f"../DATA/ELTeCfra{version}.csv", sep=";")
    
    
    #stockage des EN concatenées pour la phase d'evaluation. 
    # La concatenation des En permets une meilleure comparaison ?
    list_concat=[]
    for i in liste_ent:
        
        
        i_replace = i.replace(" ", "")
        
        list_concat.append(i_replace)
    stocker("%s-%s-concat.json"%(path,modele),list_concat)
# Out:
# ------------ ADAM TesseractFra-PNG
#           Entite Label  liste_contxt_gauche    liste_contxt_droit
# 0    Morlincourt   LOC      pauvre curé de       ! dit un\nchacun
# 1      JÆ’,F——Er   LOC    \n\nMST-M" 3'2ﬁà—       …‘_ vu.… “la—“
# 2            Las   LOC     un '\ndimanche.        ! mes camarades
# 3           Base   LOC     \n\nde même, la         devenait un br
# 4              I   LOC    —v— — _ . — ,\n\n     \n\n+0 4 MON “VIL
# ..           ...   ...                  ...                   ...
# 369           .:   LOC      l-.. $..ænY. …      ..ixﬁlê.\n\n{V...
# 370       .-flfÏ   LOC  \n\n\! 1.1: ..A\n\n  : \r...\n\n)\nÏa\n\n
# 371   .———-—-———   LOC    s de son\n\n—— ——      —……MWW…Q\n\nvoya
# 372        Paris   LOC    Q\n\nvoyage dans        , nous en serio
# 373     SOUHAITS   LOC     MON VILLAGE.\n\n   .\n\n    \n\nPremiè
#
# [374 rows x 4 columns]
# ------------ ADAM REF
#              Entite Label liste_contxt_gauche liste_contxt_droit
# 0       Morlincourt   LOC     pauvre curé de      ! dit un chacu
# 1               Las   LOC     e un dimanche.      ! mes camarade
# 2            Norine   LOC    is de presse. \n     disait, quand
# 3            Norine   LOC    n. \nLa fille à      l'avait adopté
# 4              Rose   LOC     ierre et de la      qui, dans notr
# ..              ...   ...                 ...                ...
# 166       la France   LOC     r pour aller à      que le père Ro
# 167           Paris   LOC     e son voyage à     , c'est ça qui
# 168  Saint-Brunelle   LOC     int de doute à     ! \nPRIÈRE ET S
# 169           Paris   LOC     on voyage dans     , nous en serio
# 170        SOUHAITS   LOC    nt facilités. \n   . \nPremièrement
#
# [171 rows x 4 columns]
# ------------ ADAM kraken
#             Entite Label liste_contxt_gauche liste_contxt_droit
# 0             Dicu   LOC    ort\nQue le bon      ait pitie de s
# 1            Jeac-   LOC      que le mot de    \nquet ne te por
# 2           Norine   LOC    ais de presse.\n     disait, quand
# 3              As-   LOC     ait rejetes: a    \nsure qu'il nou
# 4           Norine   LOC     n. J.a fille h      l'avaitMON VIL
# ..             ...   ...                 ...                ...
# 302      la France   LOC    r pour\naller h      que le pere Ro
# 303          Paris   LOC     e son voyage i     , c'est ca qui
# 304          Paris   LOC    on\nvoyage dans     , nous en serio
# 305   Premierement   LOC   E.\ns0UII AITS.\n    , je vous souha
# 306  dessusAotyde-   LOC     ulages, et, lh-  \nE.:c\nfuble mon
#
# [307 rows x 4 columns]

# %% [markdown]
# # Evaluation de la REN sur des données bruitées : intersections et similarités

# %%
import re
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles

#Lire les fichiers json 
def read_json (chemin):
    with open(chemin) as json_data: 
        data =json.load(json_data)
    return data

#calcul des diagrammes de Venn
def diagramme_venn(liste_en_pp, liste_en_ocr,ocr):
    font2 = {'size': 25} # use for labels
    plt.rc('font', **font2) # sets the default font 
    plt.rcParams['text.color'] = 'black' # changes default text colour
    venn2([set(liste_en_pp), set(liste_en_ocr)],set_labels = ('EN Réf', 'EN %s'%ocr),set_colors=("darkgrey", "darkblue"),alpha=0.5)

    venn2_circles(subsets=(set(liste_en_pp), set(liste_en_ocr)),linestyle="dotted", linewidth=1) 
    print(f"Analyse de la version {ocr}")     

#stockage des diagrammes de Venn au format png
def stocker_png(nom_fichier):
    plt.gcf().set_size_inches(12, 7)
    plt.subplots_adjust(left=0.03, right=0.8, top=0.9, bottom=0.1)
    plt.savefig(nom_fichier, dpi=300)
    plt.gcf()
   # plt.clf()
    return nom_fichier
 
    
path_data= "../DATA/ELTeCFRA2/*/*-concat.json"
#Stockage des données dans des structures listes pour ensuite les stocker dans une structure dictionnaire 
#utilisable avec Pandas
dict_global={}
liste_ocr=[]
liste_entit=[]
liste_vers=[]

for path in glob.glob(path_data):
    data=read_json(path)
    
    vers=path.split("/")[3]
    vers=vers.split("_")[-1]
    
    if vers!="REF":
        liste_ocr.append(vers)
      

    for entity in data:
            liste_entit.append(entity)
            liste_vers.append(vers)
            
    
        
dict_global["Entite"]=liste_entit
dict_global["version"]=liste_vers
data_tab = pd.DataFrame(dict_global)


dic_inter={}
for name_ocr in liste_ocr:
    
    

    data_ref=data_tab.query("version=='REF'" )
    data_ocr=data_tab.query("version== @name_ocr" )
   
    diagramme_venn(data_ref.Entite,data_ocr.Entite,name_ocr)
    
    dic_inter[name_ocr]={}
    intersection=set(data_ref.Entite)&set(data_ocr.Entite)
    ens_ocr=set(data_ocr.Entite)-intersection
    ens_ref=set(data_ref.Entite)-intersection
    dic_inter[name_ocr]["intersection"]=list(intersection)
    dic_inter[name_ocr]["Contamine"]=list(ens_ocr)
    dic_inter[name_ocr]["Ref"]=list(ens_ref)
  
    
    stocker_png("../DATA/INTERSECTION_GLOBALES/%s_%s_concat-intersection.png"%(name_ocr,modele))  
    plt.show()
# Out:
# Analyse de la version TesseractFra-PNG
# Analyse de la version kraken

# %%
import sklearn
from sklearn.neighbors import DistanceMetric
from sklearn.feature_extraction.text import CountVectorizer

# %%
liste2=[]
liste3=[]
liste_en1=[]
liste_en22=[]
liste_en2=[]
liste_en3=[]
dict_ent1={}
dict_ent2={}

#Réutilisation du dictionnaire "dic_inter"

for OCR, values in dic_inter.items():
    print("*****************************",OCR)
    for statut, EN in values.items():
        if statut == "intersection":
            liste1=EN
            
        if statut == "Contamine":
            liste2=EN
        if statut == "Ref":
            liste3=EN
            
            for en1 in liste1:
                for en2 in liste2:
                    if len(en1) >2 and len(en2)>2:
                        V = CountVectorizer(ngram_range=(1,4),analyzer='char')
                        X = V.fit_transform([en1, en2]).toarray()
                        distance_tab1=sklearn.metrics.pairwise.cosine_distances(X)                  
                        distance=float(distance_tab1[0][1])
                        if distance<0.35:
                            #print("EN1 : ",en1,"--","EN2 : ", en2," :", distance) 
                            liste_en1.append(en1)
                            liste_en2.append(en2)
                            
            for en2 in liste2:
                for en3 in liste3:
                    if len(en2) >2 and len(en3)>2:
                        V = CountVectorizer(ngram_range=(1,4),analyzer='char')
                        X = V.fit_transform([en2, en3]).toarray()
                        distance_tab1=sklearn.metrics.pairwise.cosine_distances(X)                  
                        distance=float(distance_tab1[0][1])

                        if distance<0.35:
                            liste_en22.append(en2)
                            liste_en3.append(en3)
                            

    dict_ent1["intersection"]=liste_en1
    dict_ent1["Contamine"]=liste_en2
    
    dict_ent2["Réf."]=liste_en3
    dict_ent2["Contamine"]=liste_en22
    

    data_tab1 = pd.DataFrame(dict_ent1)
    data_tab1=data_tab1.sort_values(by = 'Contamine')
    display(data_tab1) 
    
    data_tab2 = pd.DataFrame(dict_ent2)
    data_tab2=data_tab2.sort_values(by = 'Contamine')
    display(data_tab2)
# Out:
# ***************************** TesseractFra-PNG
#       intersection          Contamine
# 5         Clarisse  Clarisse\n\nManot
# 6        franciers             France
# 11        laFrance             France
# 8        Morlinval    GensdeMorlinval
# 12     Morlincourt       Morlinco‘urt
# 9        Morlinval      Mor—-\nlinval
# 7           duNord               Nord
# 1   Saint-Brunelle   Saint—\nBrunelle
# 4   Saint-Brunelle     Saint—Brunelle
# 3   Saint-Brunelle    Saint—Brunelle!
# 2   Saint-Brunelle       Saint—anelle
# 10        laFrance   laFrance!\n\nAh!
# 0             État               état
#            Réf.      Contamine
# 1   Reviendront    Beviendront
# 2     Franciers         France
# 3  Palais-Royal   Palais—Royal
# 4  Palais-Royal  Palais—Îloyal
# 0       Sens-tu           Sens
# ***************************** kraken
#       intersection          Contamine
# 5         Clarisse  Clarisse\n\nManot
# 19        laFrance             France
# 17       franciers             France
# 11        laFrance             France
# 6        franciers             France
# 8        Morlinval    GensdeMorlinval
# 21     Morlincourt       Mlorlincourt
# 20     Morlincourt     Morlincourttot
# 12     Morlincourt       Morlinco‘urt
# 9        Morlinval      Mor—-\nlinval
# 7           duNord               Nord
# 18          duNord               Nord
# 16          Norine            Norinel
# 15            Rose             Roseet
# 14  Saint-Brunelle   Saint-\nBrunelle
# 1   Saint-Brunelle   Saint—\nBrunelle
# 4   Saint-Brunelle     Saint—Brunelle
# 3   Saint-Brunelle    Saint—Brunelle!
# 2   Saint-Brunelle       Saint—anelle
# 13          Cachez              Tache
# 10        laFrance   laFrance!\n\nAh!
# 0             État               état
#             Réf.      Contamine
# 1    Reviendront    Beviendront
# 6        Favette     Fa-\nvette
# 2      Franciers         France
# 7      Franciers         France
# 11           Las           Lasl
# 3   Palais-Royal   Palais—Royal
# 4   Palais-Royal  Palais—Îloyal
# 5       Perpétue       Perpetue
# 0        Sens-tu           Sens
# 8     émotionnée     emotionnee
# 10       parigot       parigole
# 9        Tournez        tournee

# %% [markdown]
# # Clustering

# %%
import numpy as np
from sklearn.cluster import AffinityPropagation
from collections import OrderedDict

# %%
def nomfichier(chemin):
    nomfich= chemin.split("/")[-1]
    nomfich= nomfich.split(".")
    nomfich= ("_").join([nomfich[0],nomfich[1]])
    return nomfich
    

def stocker(chemin,contenu):                                                   
    w=open(chemin,"w")                                                         
    w.write(json.dumps(contenu, indent=2))                                     
    w.close()

# %%
path_copora = "../DATA/ELTeCFRA/DAUDET/*"

for subcorpus in glob.glob(path_copora):
    print("SUBCORPUS***",subcorpus)
    liste_nom_fichier =[]
    for path in glob.glob("%s/*lg-concat.json"%subcorpus):
#        print("PATH*****",path)
        
        nom_fichier = nomfichier(path)
        print(nom_fichier)
        liste=read_json(path)  
    #print(liste)        
#### FREQUENCE ########
        
        dic_mots={}
        i=0
    
        
        for mot in liste: 
            
            if mot not in dic_mots:
                dic_mots[mot] = 1
            else:
                dic_mots[mot] += 1
                #dic_langues[langue][mot] = dic_langues[langue][mot] + 1
        
        i += 1
        #    print(dic_mots)
        new_d = OrderedDict(sorted(dic_mots.items(), key=lambda t: t[0]))
        
#        print(new_d)
        freq=len(dic_mots.keys())      
#### VECTORISATION

        Set_00 = set(liste)
        Liste_00 = list(Set_00)
        dic_output = {}
        liste_words=[]
        matrice=[]
        
        for l in Liste_00:
            if len(l)!=1:
                liste_words.append(l)

        try:
            words = np.asarray(liste_words) #So that indexing with a list will work
            for w in words:
                liste_vecteur=[]
            
                    
                for w2 in words:
                
                        V = CountVectorizer(ngram_range=(2,3), analyzer='char') 
                        X = V.fit_transform([w,w2]).toarray()
                        distance_tab1=sklearn.metrics.pairwise.cosine_distances(X) # Distance avec cosinus            
                        liste_vecteur.append(distance_tab1[0][1])
                    
            #    print(liste_vecteur)
            
            
            #  
                matrice.append(liste_vecteur)
            matrice_def=-1*np.array(matrice)
            #print(matrice)
            
    ##### CLUSTER
                  
            affprop = AffinityPropagation(affinity="precomputed", damping= 0.5, random_state = None) 
    
            affprop.fit(matrice_def)
            for cluster_id in np.unique(affprop.labels_):
                exemplar = words[affprop.cluster_centers_indices_[cluster_id]]
                cluster = np.unique(words[np.nonzero(affprop.labels_==cluster_id)])
                cluster_str = ", ".join(cluster)
                cluster_list = cluster_str.split(", ")
            #                print(" - *%s:* %s" % (exemplar, cluster_str))                
                Id = "ID "+str(i)
                for cle, dic in new_d.items(): 
                    if cle == exemplar:
                        dic_output[Id] ={}
                        dic_output[Id]["Centroïde"] = exemplar
                        dic_output[Id]["Freq. centroide"] = dic
                        dic_output[Id]["Termes"] = cluster_list
                
                i=i+1
            #print(dic_output)
            data_cluster = pd.DataFrame(dic_output)
            display(data_cluster) 
            
            #stocker("%s/%s_cluster-consinus-2-3-clean.json"%(subcorpus,nom_fichier),dic_output)

        except :        
            print("**********Non OK***********", path)

    
            liste_nom_fichier.append(path)
           # stocker("%s/fichier_non_cluster.json"%subcorpus, liste_nom_fichier)
            
            continue 
#
# Out:
# SUBCORPUS*** ../DATA/ELTeCFRA/DAUDET/DAUDET_kraken
# DAUDET_petit-chose_Kraken-base_txt_spacy-lg-concat
#                                                               ID 1  \
# Centroïde                                                 Cevenole
# Freq. centroide                                                  1
# Termes           [1N, Cevenol, Cevenole, Cunocepa, I43\nCevenol...
#
#                                                  ID 2  \
# Centroïde                                    credence
# Freq. centroide                                     1
# Termes           [Providence, ceda, credence, radede]
#
#                                                           ID 3        ID 4  \
# Centroïde                                         Palais-Royal         I47
# Freq. centroide                                              1           1
# Termes           [Kalatala, Palais-Mazarin, Palais-Royal, yAZ]  [I47, I49]
#
#                                                            ID 5  \
# Centroïde                                                 Frinc
# Freq. centroide                                               1
# Termes           [Afrique, FR, Frinc, NC2, Port-au-Prince, Rio]
#
#                                                               ID 6  \
# Centroïde                                                    Rienl
# Freq. centroide                                                  1
# Termes           [Algerien, Bientot, Combien, Reveries, Rienl, ...
#
#                                             ID 7  \
# Centroïde                                     C-
# Freq. centroide                                1
# Termes           [C-, C-\n\nZA\n3.-\n\nR, gr-c-]
#
#                                                       ID 8  \
# Centroïde                                      hotelPilois
# Freq. centroide                                          1
# Termes           [Pilois, hote, hotelPilois, hotelPiloisl]
#
#                                                  ID 9  \
# Centroïde                                  Langlumeau
# Freq. centroide                                     1
# Termes           [Langlumeau, Languedoc, N3, deplume]
#
#                                                              ID 10  ...  \
# Centroïde                                                 Eyssette  ...
# Freq. centroide                                                 45  ...
# Termes           [Eyssette, Eyssettel, Eyssettte, MPEyssettel, ...  ...
#
#                                                   ID 77  \
# Centroïde                                          N\nP
# Freq. centroide                                       1
# Termes           [A4\n\n\nd\n'N\nM\n\n, N\nEZEYt, N\nP]
#
#                                                              ID 78  \
# Centroïde                                              abbeGermane
# Freq. centroide                                                 24
# Termes           [1'abbeGermane, 1E., Lakamana, abbe, abbe\nGer...
#
#                                                              ID 79  \
# Centroïde                                      E\ne-z.L5----\n\n17
# Freq. centroide                                                  1
# Termes           [.G\n\n-\n\n', 3z-E\nE\nWr\nA, E\ne-z.L5----\n...
#
#                                                              ID 80  \
# Centroïde                                             Saint-Nizier
# Freq. centroide                                                 10
# Termes           [Saint-\nNizier, Saint-\nNizierl\n, Saint-Nizi...
#
#                                                              ID 81  \
# Centroïde                                                  Italien
# Freq. centroide                                                  1
# Termes           [Italien, Italiens, N\n\ntA\n\n\n1, d'Italie, ...
#
#                                                              ID 82  \
# Centroïde                                                    Chine
# Freq. centroide                                                  1
# Termes           [Chili, Chine, Chinois, Colombine, Philistine,...
#
#                                                              ID 83  \
# Centroïde                                                Pierrotte
# Freq. centroide                                                128
# Termes           [Pierrotte, Pierrotte\nPierrotte, Pierrotte-qu...
#
#                                                              ID 84      ID 85  \
# Centroïde                                                    Venez        I.E
# Freq. centroide                                                  1          1
# Termes           [Cenevol, Necro-, ParfaitlVenez, RBvE, Rh6ne, ...  [I', I.E]
#
#                                                              ID 86
# Centroïde                                                  College
# Freq. centroide                                                  1
# Termes           [Batignolleslo, College, Mlol, Recollets, Vieu...
#
# [3 rows x 86 columns]
# SUBCORPUS*** ../DATA/ELTeCFRA/DAUDET/DAUDET_TesseractFra-PNG
# DAUDET_petit-chose_TesseractFra-PNG_txt_spacy-lg-concat
#                                                    ID 1  \
# Centroïde                                    Barbette!.
# Freq. centroide                                       1
# Termes           [Arabes, BE, Barbette!., caféBarbette]
#
#                                                               ID 2  \
# Centroïde                                             Coucou-Blanc
# Freq. centroide                                                 23
# Termes           [Annou, Boucoyran, Coucou-\nBlanc, Coucou-Blan...
#
#                                                            ID 3  \
# Centroïde                                               Muguets
# Freq. centroide                                               3
# Termes           [Bouzanquet, Languedoc, Muguets, Rà, leMuguet]
#
#                                                       ID 4  \
# Centroïde                                              Tan
# Freq. centroide                                          1
# Termes           [Daniel, Fanfan-la-Tulipe, TA, Tan, mans]
#
#                                                               ID 5  \
# Centroïde                                                       ER
# Freq. centroide                                                  3
# Termes           [Brûler, ER, Observatoire, Palerme, Ser-, TIRE...
#
#                                                               ID 6  \
# Centroïde                                                 Sarlande
# Freq. centroide                                                 12
# Termes           [Inde, JardindesPlantes, Sar-, Sarlandais, Sar...
#
#                                                               ID 7  \
# Centroïde                                                    rue\n
# Freq. centroide                                                  1
# Termes           [ATRUE, Lx, Pb, rue\n, rueBonaparte, rueLanterne]
#
#                                                               ID 8  \
# Centroïde                                            Saint-Germain
# Freq. centroide                                                  6
# Termes           [Maine, Prés-Saint-Gervais, Saint-Germain, Sai...
#
#                                                    ID 9  \
# Centroïde                                         mencé
# Freq. centroide                                       1
# Termes           [Confusément, Providence, Rome, mencé]
#
#                                            ID 10  ...  \
# Centroïde                                 Bamban  ...
# Freq. centroide                               16  ...
# Termes           [Bach’, Bamban, Bamban!., Cuba]  ...
#
#                                                              ID 47  \
# Centroïde                                                Pierrotte
# Freq. centroide                                                140
# Termes           [MiePierrotte, MilePierrotte, Nécro-, Pierrott...
#
#                                                              ID 48  \
# Centroïde                                                  TES\n\n
# Freq. centroide                                                  1
# Termes           [Amalécites, Carmélites, Château-\nNeuf-des-Pa...
#
#                                                              ID 49  \
# Centroïde                                                  Jacques
# Freq. centroide                                                  1
# Termes           [ENLÈVEMENT219\n\nAt\n\n\n\n\n\nJacques, Facqu...
#
#                                        ID 50           ID 51  \
# Centroïde                             Naples            kohl
# Freq. centroide                            2               1
# Termes           [Cap, Naples, baiedeNaples]  [Bohême, kohl]
#
#                                                              ID 52  \
# Centroïde                                                  Prairie
# Freq. centroide                                                  1
# Termes           [Araignée, Désir-de-plaire, Grand-Orient, Prai...
#
#                                                 ID 53  \
# Centroïde                                    Regardez
# Freq. centroide                                     1
# Termes           [Chardon, Regardez, gardes-du-corps]
#
#                                                           ID 54  \
# Centroïde                                                Alfort
# Freq. centroide                                               1
# Termes           [Alfort, Port-au-Prince, Porte, Écoled’Alfort]
#
#                                                              ID 55  \
# Centroïde                                            collègedeLyon
# Freq. centroide                                                  2
# Termes           [Lyon, Vieux-Collège, collègecèlèbrelasaintThé...
#
#                                                          ID 56
# Centroïde                                             Pilois!.
# Freq. centroide                                              1
# Termes           [Pilois, Pilois!., Pilouitt!., grésil, kss!.]
#
# [3 rows x 56 columns]

# %%
import matplotlib.pyplot as plt
import csv
import seaborn as sns
sns.set(style="whitegrid")


def nomfichier(chemin):
    nomfich= chemin.split("/")[-1]
    nomfich= nomfich.split(".")
    nomfich= ("_").join([nomfich[0]])
    return nomfich

centro=[]
cluster=[]
i=0

#iy=1
#centro=[]
#cluster=[]
liste_resultat=[]

file_path="../DATA/SPACY_ANNOT/DAUDET/DAUDET_petit-chose_Kraken-base_txt_lg_spacy_cluster-cosinus-2-3_ANNOT.csv"

with open(file_path, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=';', quotechar=' ')
    next(spamreader)
    
    for row in spamreader:
#        print(row)
        liste_resultat.append(row)

for liste in liste_resultat:
 

    if liste[-1]=="":
        centro.append([liste[1],liste[-2]])
    else:
        cluster.append([liste[1],liste[2],liste[-1]])
            
#print(cluster)
for cl in cluster:
#            for centr in centro:
#                if cl[0]==centr[0]:
#                    centr.append(cl)
 
    if cl[0]==centro[i][0]:

        centro[i].append(cl)
#        print("Pareil",cl[0],centro[i][0])

    else:
#        #        print("*************PAS Pareil",cl[0],centro[i][0])
        i=i+1
        centro[i].append(cl)

        
tableau={}
liste_label_centro=[]
liste_label_cluster=[]
liste_statut_centro=[]
liste_statut_cluster=[]
liste_ix=[]
liste_resultat_dist2=[]
liste_lower=[]
ix=0
icl=0

liste_resultat_dist_low=[]

for ce in centro:   
#    ix+=10
    ix=(ix+100)-ix%100
    icl=0
    for j in ce[2:]:
        
        if ce[0]==j[1]:
            liste_ix.append(ix)
        else:       
            icl=icl+50
            liste_ix.append(ix+icl)

            
        V = CountVectorizer(ngram_range=(2,3), analyzer='char')
        #lower case =True par défaut
        X = V.fit_transform([j[0],j[1]]).toarray()
       
        ### Distance Cosinus
        distance_tab1=sklearn.metrics.pairwise.cosine_distances(X) 
        liste_resultat_dist2.append(distance_tab1[0][1])
 
         
        liste_statut_centro.append(ce[1])
        liste_label_centro.append(ce[0])
        liste_label_cluster.append(j[1])
        liste_statut_cluster.append(j[2])
    ix+=icl
    #print(liste_ix)

## CKP : Moyenne Distance, regularisation casse (pas utile selon les tests)

       

#liste_moy=[]
#for jl in liste_lower:
#    
#    V_lower = CountVectorizer(ngram_range=(2,3), analyzer='char') 
#    Xlower = V_lower.fit_transform([jl[0],jl[1]]).toarray()
#    distance_tab_low=sklearn.metrics.pairwise.cosine_distances(Xlower) 
#    liste_resultat_dist_low.append(distance_tab_low[0][1])

    
#moy_zip=zip(liste_resultat_dist2,liste_resultat_dist_low)  
#for idd in moy_zip:
#    if idd[0]!= idd[1]:
#        print(idd[0],idd[1])
    
    
coord_zip=zip(liste_resultat_dist2,liste_ix) 
#print (list(test_zip))
coord=[]
coord_cl=[]
for ind in list(coord_zip):
    coord_cl.append(ind)
#    print(ind[0])
    if ind[0]==0.0:
        coord.append(ind)
#        print(ind)

liste_centr=[]
for ce in centro: 
    liste_centr.append(ce[0]) 

liste_clus=[]
for cl in cluster:
    liste_clus.append(cl[1])
#print(liste_clus)
    
groups={}

for l,c in zip(liste_centr,coord): 
    groups[l]={}
    groups[l]=c
    
groups_cl={}
for lc,cc in zip(liste_clus,coord_cl): 
    groups_cl[lc]={}
    groups_cl[lc]=cc


tableau["label_centro"]=liste_label_centro
tableau["label_cluster"]=liste_label_cluster
tableau["Statut_cluster"]=liste_statut_cluster
tableau["Statut_centro"]=liste_statut_centro
tableau["Distances cosinus"]=liste_resultat_dist2
tableau["Centroïdes"]=liste_ix
        
      
data = pd.DataFrame(tableau)

data.head()

#y_min=0
#y_max=1000

facet2=sns.relplot(data=data, x="Distances cosinus", y="Centroïdes", hue="label_centro", style="Statut_cluster",s=40)
facet2.set_yticklabels([])
#Permet de changer la taille de la figure
plt.gcf().set_size_inches(25, 25)

for key, values in groups_cl.items():            
        plt.annotate(key,values, horizontalalignment='right', verticalalignment='top',
                     size=5, weight='bold')           

        #La figure est stockée au bout du chemin suivant 
plt.savefig("../DATA/OUTPUT_CLUSTER/DAUDET_petit-chose_Kraken-base_lg_spacy_cluster-cosinus-2-3_ANNOT_ok.png",dpi=300, bbox_inches="tight")

# %% [markdown]
# <img src="../DATA/images/DAUDET_cluster2.png">

# %% [markdown]
# # Représenter les résultats sur une carte
# <h3>Cas d'usage</h3>
# <h3>Un collègue chercheur en Lettres a besoin d'un programme qui récupère sur 800 romans OCRisés :
#     <br>
#  - les entités nommées,
#     <br>
#  - les contextes gauches et droits,
#     <br>
#  - différentes métadonnées.
#     <br>
#     Il veut récupérer toutes les EN, mais souhaite que les EN LOC soient **géolocalisées**.</h3>
#
# Problèmes 1 : Le géocodeur ne **trouve pas toujours** de géolocalisation pour une EN.
#
# Commentaires :
#  - le géocodeur sert de filtre : il ne s'agit pas d'une EN, c'est du **bruit**,
#  - il n'y en a **pas beaucoup** par fichier.
#       - **Solution : Complétion à la main dans un fichier csv.**
#  - il y en a beaucoup trop il faut améliorer le programme de geocoding ?
#
# Problèmes 2 : Le géocodeur **trouve** la géolocalisation pour une EN LOC, qui en fait est du bruit :
# - **c'est vrai il y en a, mais c'est toujours moins long que de corriger tous le texte à la main ?**
#     - **Solution** : changement de label et supression de la localisation à la main dans un fichier csv.

# %%
import csv
import glob
import spacy
from geopy.geocoders import Nominatim
from collections import OrderedDict



def lire_fichier (chemin):
    f = open(chemin , encoding = 'utf−8')
    chaine = f.read ()
    f.close ()
    return chaine


def titre_auteur(chemin):
    nomfich= chemin.split("/")[-1]
    nomfich= nomfich.split(".")[0]
    nomfich= nomfich.split("_")
    # nomfich= nomfich.upper()
    # nomfich= ("_").join([nomfich[0]])
    return nomfich

## MAIN
y=0
geo_flag=0

path_corpora = "../DATA/ELTeCFRA/DAUDET/DAUDET_TesseractFra-PNG/*.txt"

list_resultats=[]
liste_res=[]


nlp = spacy.load("fr_core_news_lg")
nlp.max_length = 3508822 
for path in glob.glob(path_corpora):
    print(path)
    titreauteur=titre_auteur(path)   
    texte = lire_fichier(path)
    text=nlp(texte)       
    liste_tok=[]
    for token in text:
        liste_tok.append(token.text)
    
    for ent in text.ents:
        list_resultats.append([titreauteur[0],titreauteur[1],len(liste_tok),ent.text, ent.start_char, ent.end_char, ent.label_,texte[ent.start_char-200:ent.start_char],texte[ent.end_char:ent.end_char+200]])
        

for i in list_resultats:

    start_caract = i[4]
    end_caract =i[5]
    # print(start_caract,end_caract)
    if i[-3]=="LOC":
        # print(i)
        ## Geolocalisation avec Nominatim
        try:
            res = i[3].replace("\n\n", "")
            geolocator = Nominatim(user_agent="htpss")
            location = geolocator.geocode(i[3],timeout=30)
            liste_res.append([i[0],i[1],"année ",i[2],i[3],i[-3],location.latitude ,location.longitude,i[4],i[5],i[-2],i[-1]])
            print("OK",i[3],i[-3])
        except:
            ## On gère les exceptions : il y a une EN labelisée LOC mais pas de geoloc.
                print("!!! Pas de localisation pour le LOC : ", i[3])
                liste_res.append([i[0],i[1]," année",i[2],i[3],i[-3],"None","None",i[4],i[5],i[-2],i[-1]])
                continue
    else:
        liste_res.append([i[0],i[1],"année ",i[2],i[3],i[-3],"None ","None",i[4],i[5],i[-2],i[-1]])
        #print("Entité label autre :",i[3],",",i[-3])

## Stockage au format .csv  
## Utilisation dans GoogleMymap : paramétrage du delimiter avec une "," à la place du ";"
with open("../DATA/OUTPUT_CSV/toto.csv", 'w', newline='', encoding = 'utf−8') as csvfile:
            spamwriter = csv.writer(csvfile, delimiter=';', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            spamwriter.writerow(["auteur"]+["titre"]+["annee"]+["nb_tokens_texte"]+["Entite"] + ["Label"]+["latitude"]+["longitude"]+["caractere_debut"]+["caractere_fin"]+["contexte_gauche"]+["contexte_droit"])  
            for res in liste_res:
                spamwriter.writerow(res)
# Out:
# ../DATA/ELTeCFRA/DAUDET/DAUDET_TesseractFra-PNG/DAUDET_petit-chose_TesseractFra-PNG.txt
# OK Languedoc LOC
# OK Midi LOC
# OK Carmélites LOC
# OK romains LOC
# OK Bibliothèque nationale de France LOC
# OK Eyssette LOC
# OK Annou LOC
# OK Marseille LOC
# OK Marseille LOC
# OK Marseille LOC
# OK Annou LOC
# OK Eyssette LOC
# OK Annou LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Annou LOC
# OK Annou LOC
# OK m'’appelais LOC
# OK Océan LOC
# OK vages LOC
# OK Eyssette LOC
# OK Récollets LOC
# OK Récollets LOC
# OK Vendredi LOC
# OK Î LOC
# OK Lyon LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Annou LOC
# OK Beaucaire LOC
# OK Annou LOC
# OK Lyon LOC
# OK le Rhône LOC
# OK Montélimart LOC
# OK Le Rhône LOC
# OK Midi LOC
# OK du Nord LOC
# OK Lyon LOC
# OK Lyon LOC
# !!! Pas de localisation pour le LOC :  Confusément
# OK Annou LOC
# OK Annou LOC
# !!! Pas de localisation pour le LOC :  Pécaiïre
# OK Annou LOC
# OK Lyon LOC
# OK Annou LOC
# OK Rhône LOC
# OK Midi LOC
# OK Perrache LOC
# OK Eyssette LOC
# OK Midi LOC
# OK Midi LOC
# OK Annou LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Saint-Nizier LOC
# OK Saint-
# Nizier LOC
# OK suisse LOC
# OK Midi LOC
# OK collège de Lyon LOC
# OK Lyon LOC
# OK A TRUE LOC
# !!! Pas de localisation pour le LOC :  Î as {
#
# Ps
#
# A ii
#
# D
# OK place des
# Terreaux LOC
# OK rue Lanterne LOC
# OK Saint-
# Nizier LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK croisée LOC
# OK Ë LOC
# OK Lyon LOC
# OK Eyssette LOC
# OK Saint-Nizier LOC
# OK Midi LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Midi LOC
# OK Lyon LOC
# OK pagna LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Montélimart LOC
# OK Annou LOC
# !!! Pas de localisation pour le LOC :  Mne Evyssette
# OK Sois LOC
# OK Lyon LOC
# OK là-bas LOC
# OK Rhône LOC
# OK Vienne LOC
# OK Montélimart LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Annou LOC
# OK Annou LOC
# OK Annou LOC
# OK Eyssette LOC
# OK Annou LOC
# !!! Pas de localisation pour le LOC :  Château-
# Neuf-des-Papes
# OK Annou LOC
# OK Annou LOC
# OK vieille Fe LOC
# OK Annou LOC
# OK Lyon LOC
# OK rue Lanterne LOC
# OK Annou LOC
# OK Petit Chose LOC
# OK Angleterre LOC
# OK Carmélites LOC
# OK Cévennes LOC
# OK Ser- LOC
# OK TA LOC
# OK tâtons LOC
# OK Sarlande LOC
# OK Afrique LOC
# OK Eyssette LOC
# OK Serrières LOC
# OK Serrières LOC
# OK Sarlande LOC
# OK Serrières LOC
# OK Lyon LOC
# OK Serrières LOC
# OK Est LOC
# OK Eyssette LOC
# OK Frinc LOC
# !!! Pas de localisation pour le LOC :  portier Cassagne
# OK Arabes LOC
# OK café Barbette LOC
# OK Eyssette LOC
# OK la Prairie LOC
# !!! Pas de localisation pour le LOC :  m'’invitait
# OK la Prairie LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK la Prairie LOC
# OK collège de Lyon LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban!. LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Prairie LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK ER LOC
# OK TES
#
#  LOC
# OK Cévennes LOC
# OK Bouzanquet LOC
# OK Eyssette LOC
# OK Sarlande LOC
# OK Eyssette LOC
# OK Vieux-Collège LOC
# OK califourchon LOC
# OK Est LOC
# OK Est LOC
# OK Place! LOC
# OK terre LOC
# OK Frinc LOC
# OK Est LOC
# OK Est LOC
# OK Eyssette LOC
# OK Cévennes LOC
# OK Cévennes LOC
# !!! Pas de localisation pour le LOC :  65
#
# Sd
# OK Horreur!. LOC
# !!! Pas de localisation pour le LOC :  collège cèlèbre la saint Théophile
# OK Limoux LOC
# OK LL Sd LOC
# OK la Prairie LOC
# OK Limoux LOC
# OK Frinc LOC
# OK Saint-Théophile LOC
# OK kss!. LOC
# OK kss!. LOC
# OK Saint-Théophile LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Sarlandais LOC
# OK Sarlande LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK TE LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Petit-Cercle LOC
# OK Grand-Cercle LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK la Prairie LOC
# OK Evêché LOC
# OK gardes-du-corps LOC
# OK café Barbette LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Paris LOC
# OK Ê LOC
# OK Î LOC
# OK Fanfan-la-Tulipe LOC
# OK Est LOC
# OK Paris LOC
# OK È LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK Lyon LOC
# OK Saint-Nizier LOC
# OK Providence LOC
# OK Paris LOC
# OK Sarlande LOC
# OK Bretagne LOC
# OK d’Espagne LOC
# OK Quartier Latin LOC
# OK Quartier
# Latin! LOC
# OK Est LOC
# OK OR
#
# 84 LE PETIT LOC
# OK tournai LOC
# OK Sarlande LOC
# !!! Pas de localisation pour le LOC :  m'’effraya
# OK Paris LOC
# OK Paris LOC
# OK la Prairie LOC
# OK la Prairie LOC
# OK Sarlande LOC
# OK la Prairie LOC
# OK la Prairie LOC
# OK Paris LOC
# OK la Prairie LOC
# OK TE LOC
# OK Eyssette LOC
# OK Sarlande LOC
# OK Sarlande LOC
# OK Eyssette LOC
# OK rue Bonaparte LOC
# OK Paris LOC
# !!! Pas de localisation pour le LOC :  FER 95
#
# St dd
# OK Paris LOC
# OK Paris LOC
# OK Eyssette LOC
# OK Est LOC
# OK Eyssette LOC
# !!! Pas de localisation pour le LOC :  ILE
#
# 2e ee 2er
# OK place d’Armes LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Barbette!. LOC
# OK Sonne LOC
# OK Paris LOC
# OK Eyssette LOC
# OK Quartier- LOC
# !!! Pas de localisation pour le LOC :  Charivaris
# OK Eyssette LOC
# OK Eyssette LOC
# OK È LOC
# OK Paris LOC
# OK Paris LOC
# OK Eu LOC
# OK Eu LOC
# OK l'Afrique LOC
# OK Paris LOC
# OK grésil LOC
# OK Champenoise LOC
# OK Paris LOC
# OK Champenoise LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK Quartier-Latin LOC
# OK Paris LOC
# OK Paris LOC
# OK Jardin des Plantes LOC
# OK Paris LOC
# OK Saint-Germain-des-Prés LOC
# OK clocher de Saint-Germain LOC
# OK Paris LOC
# OK Eyssette LOC
# OK Eu us ns LOC
# OK la Bretagne LOC
# OK rue Lanterne LOC
# OK Lyon LOC
# OK Annou LOC
# OK Lyon LOC
# OK du Nord LOC
# OK rue Lanterne LOC
# OK Lyon LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Paris LOC
# OK Paris LOC
# OK Saint-Nizier LOC
# OK faubourg Saint-Germain LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK faubourg Saint-Germain LOC
# OK rue de Lille LOC
# OK rue
#  LOC
# OK Saint-Guillaume LOC
# OK Saint-Nizier LOC
# !!! Pas de localisation pour le LOC :  m'’introduire
# OK Saint-Nizier LOC
# OK rue de Lille LOC
# OK BE LOC
# OK Saint-
# Nizier LOC
# OK rue Saint-Guillaume LOC
# OK Saint-Nizier LOC
# OK rue Saint-Guillaume LOC
# OK rue Saint-Guillaume LOC
# OK Saint-Nizier LOC
# OK Saint-Nizier LOC
# OK Saint-Nizier LOC
# OK Saint-Nizier LOC
# OK Saint-
# Nizier LOC
# OK Paris LOC
# OK rue Saint-Guillaume LOC
# OK rue de Lille LOC
# OK Hacqueville LOC
# OK Saint-Nizier LOC
# OK Paris LOC
# OK Hacqueville LOC
# OK Pérou LOC
# OK Hacqueville LOC
# OK Lx LOC
# OK Italie LOC
# OK Moustier LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Cévennes LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK mienne LOC
# OK Sarlande LOC
# OK Lyon LOC
# OK Hacqueville LOC
# OK clocher de Saint-Germain LOC
# OK Saint-Germain LOC
# OK Paris LOC
# OK Parisien LOC
# OK Paris LOC
# OK Saint-Germain-des-
# Prés LOC
# OK Rome LOC
# OK clocher de Saint-Germain LOC
# OK I LOC
# OK Parisien LOC
# OK Lyon LOC
# OK Paris LOC
# OK sur-le-champ LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Sapristi LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Sarlande LOC
# OK la Prairie LOC
# OK Comédie-Française LOC
# OK Magnifique LOC
# OK F LOC
# OK Foin LOC
# OK pyramide d'Egypte LOC
# OK Palais-Mazarin LOC
# OK n'’irai LOC
# OK Saint- LOC
# OK rue Saint-Benoît LOC
# OK califourchon LOC
# OK Allons LOC
# OK È LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Tiens LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK Lyon LOC
# OK rue Lanterne LOC
# OK Saint-Germain LOC
# OK REP LOC
# OK Coucou-Blanc! LOC
# OK Saint-Germain-des-Prés LOC
# OK Daniel LOC
# OK Saint-Germain LOC
# OK ER LOC
# OK Saint-Germain LOC
# OK rue Saint-Benoît LOC
# OK Luxembourg LOC
# OK Pierrotte LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Musette LOC
# OK Nanterre LOC
# !!! Pas de localisation pour le LOC :  Tologototignan
# OK mans LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Cap LOC
# OK Coucou-
# Blanc LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  irons /à-bas
# OK Pierrotte LOC
# OK Palais-Royal LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Cévennes LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK RCE LOC
# OK Pierrotte LOC
# OK Eyssette LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Eyssette LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Cévennes LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Montmartre LOC
# !!! Pas de localisation pour le LOC :  Anastagille
# !!! Pas de localisation pour le LOC :  Anastagille
# !!! Pas de localisation pour le LOC :  Anastagille
# OK Pierrotte LOC
# OK Montmartre LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Parisiens LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Parisiens LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  mer
#
#
#
#
#
#
#
#
#
# LE ROMAN
# OK Languedoc LOC
# OK Pierrotte!
#
# Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Anastagille
# OK Pierrotte LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Bohême LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# OK Pierrotte LOC
# OK Saumon LOC
# OK Est LOC
# OK tournai LOC
# OK tournai LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK Pierrotte LOC
# OK Rosellen LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# !!! Pas de localisation pour le LOC :  Amalécites
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mile Coucou-Blanc
# OK Coucou-Blanc LOC
# OK Pierrotte LOC
# OK Coucou-Blanc LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK Allons LOC
# OK Pierrotte LOC
# OK Bach’ LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK clocher de Saint-Germain LOC
# OK Saumon LOC
# OK Porcelaines LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK Philistine LOC
# OK Pierrotte LOC
# OK clocher de Saint-Germain LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Est LOC
# !!! Pas de localisation pour le LOC :  Mile Coucou
# OK Coucou-Blanc LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK «Ce LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK ner là-bas LOC
# OK tES
#
# EE LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Rosellen LOC
# OK cs LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Désir-de-plaire
# OK clocher de Saint-Germain LOC
# OK Jacques LOC
# OK bordeaux LOC
# !!! Pas de localisation pour le LOC :  Lakçamana
# !!! Pas de localisation pour le LOC :  Kalatçala
# OK Çudra LOC
# !!! Pas de localisation pour le LOC :  Cunocépa
# !!! Pas de localisation pour le LOC :  Viçva-
# OK mitra LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK École d’Alfort LOC
# OK Grand-Orient LOC
# OK Fougeroux LOC
# OK Pierrotte LOC
# OK Sar- LOC
# OK Pierrotte LOC
# OK I LOC
# OK le Muguet LOC
# OK Araignée LOC
# OK Suis LOC
# OK P LOC
# OK Muguets LOC
# OK Muguets LOC
# OK Muguets LOC
# OK Bas LOC
# OK Chardon LOC
# OK A LOC
# !!! Pas de localisation pour le LOC :  Nécro-
# OK cimetière des Papillons LOC
# OK VENDRAS LOC
# OK Caveau LOC
# OK Alfort LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Malheureuse- LOC
# OK Observatoire LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK PSS Sd
#
#
#
# LL LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Rosellen LOC
# OK Vénus LOC
# OK TIRER LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Ê LOC
# OK Alsacien LOC
# OK A LOC
# OK SRE LOC
# OK VENDRAS LOC
# OK clocher de Saint-Germain LOC
# OK Pierrotte LOC
# OK Odéon LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Saint-Benoît LOC
# OK Paris LOC
# OK Eyssette LOC
# OK Jardin des Plantes LOC
# OK fe LOC
# OK Théâtre-Français LOC
# !!! Pas de localisation pour le LOC :  huppe jaune
# OK îles Marquises LOC
# !!! Pas de localisation pour le LOC :  kakatoès
# OK Théâtre- LOC
# OK Français LOC
# OK îles Marquises LOC
# OK VENDRAS LOC
# OK Eyssette LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# OK Pierrotte LOC
# OK baie de Naples LOC
# OK Coucou-Blanc LOC
# OK Ebloui LOC
# OK Colombine LOC
# OK I LOC
# !!! Pas de localisation pour le LOC :  Saint-Pétesbourg
# OK Naples LOC
# OK îles Marquises LOC
# OK Port-au-Prince LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Théâtre-Français LOC
# OK Saumon LOC
# OK Porte LOC
# OK Tan LOC
# OK Saint-Germain LOC
# OK Nice LOC
# OK Hacqueville LOC
# OK Chili LOC
# OK victoria LOC
# OK Coucou-Blanc LOC
# OK Hacqueville LOC
# OK l'Italie LOC
# OK Rome LOC
# OK Naples LOC
# OK Pise LOC
# OK Palerme LOC
# !!! Pas de localisation pour le LOC :  Facques
# OK Eyssette LOC
# OK Pise LOC
# OK Cuba LOC
# OK Est LOC
# OK Est LOC
# OK Parthénon LOC
# !!! Pas de localisation pour le LOC :  mastoïdes
# OK Turc LOC
# OK Turc LOC
# OK Italien LOC
# OK tiennes LOC
# OK Turc LOC
# OK Est LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Porcelaines LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Prés-Saint-Gervais LOC
# OK Turc LOC
# OK théâtre de Paris LOC
# OK Éliacin LOC
# !!! Pas de localisation pour le LOC :  Consterna-
# OK ER LOC
# OK Gymnase LOC
# OK Théâtre-Français LOC
# OK Cuba LOC
# OK Coucou-Blanc LOC
# OK Turc LOC
# OK là-bas LOC
# OK Turc LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK boulevard Montparnasse LOC
# OK Coucou-Blanc LOC
# OK Rà LOC
# OK Coucou-Blanc LOC
# !!! Pas de localisation pour le LOC :  miséra-a-ble!
# OK Coucou-Blanc LOC
# OK titis LOC
# OK Grenelle LOC
# OK Mont- LOC
# OK Sèvres LOC
# OK Sceaux LOC
# OK Saint-Cloud LOC
# OK È LOC
# OK F LOC
# !!! Pas de localisation pour le LOC :  Souwaroff
# OK Lovelaces LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Maine LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK kohl LOC
# !!! Pas de localisation pour le LOC :  Langlumeau
# OK Pierrotte LOC
# OK théâtre Montparnasse LOC
# OK Rue des Dames LOC
# OK Batignolles LOC
# OK Paris LOC
# OK Palerme LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK rue Bonaparte LOC
# OK Paris LOC
# OK Alsace LOC
# OK Regardez LOC
# OK Alsacien LOC
# OK Alsacien LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Chinois LOC
# OK Bohême LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  ENLÈVEMENT 219
#
# At
#
#
#
#
#
# Jacques
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Alsacien LOC
# OK Saint-Germain LOC
# OK Providence LOC
# OK Montparnasse LOC
# OK tour de Saint-Germain LOC
# OK Pilois LOC
# OK rue des Dames LOC
# OK Hacqueville LOC
# OK Marsala LOC
# OK des Batignolles LOC
# OK Mont- LOC
# OK Alsace LOC
# OK théâtre Montparnasse LOC
# !!! Pas de localisation pour le LOC :  Marie-feanne
# OK Luxembourg LOC
# OK mencé LOC
# !!! Pas de localisation pour le LOC :  Pilouitt!.
# OK Italiens LOC
# OK Paris LOC
# OK Pilois LOC
# OK Paris LOC
# OK clocher de Saint-Germain LOC
# OK Est LOC
# OK Est LOC
# OK sûmes LOC
# OK Pardieu LOC
# OK Paris LOC
# OK Allons LOC
# OK Ê LOC
# OK Pilois LOC
# OK Pierrotte LOC
# OK Montparnasse LOC
# OK Montparnasse LOC
# OK Est LOC
# OK Est LOC
# !!! Pas de localisation pour le LOC :  lamoelle de sos
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Pierrotte LOC
# OK Coucou-Blanc LOC
# OK Montmartre LOC
# OK Inde LOC
# OK Pilois LOC
# OK Lyon LOC
# OK Pilois LOC
# OK A LOC
# OK Pilois LOC
# OK Pilois!. LOC
# OK EE LOC
# OK Nice LOC
# OK Saint-Pierre LOC
# OK Sarlande LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Ià-bas LOC
# OK Paris LOC
# OK église Saint-Pierre LOC
# OK Montmartre LOC
# OK Paris LOC
# OK Midi LOC
# OK Pilois LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Montmartre LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Pb LOC
# !!! Pas de localisation pour le LOC :  Rime am
#
# EPS
#
# 244
# !!! Pas de localisation pour le LOC :  Pourvu
# OK là-bas LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saint-Emilion LOC
# !!! Pas de localisation pour le LOC :  om
#
# ru térmiétpe der
#
# En
#
# 246 LE PETIT
# OK Pierrotte LOC
# OK Montmartre LOC
# OK Providence LOC
# OK Eyssette LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Montparnasse LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Brûler LOC
# !!! Pas de localisation pour le LOC :  Madagas-
# OK Rana-Valo LOC
# OK Paris LOC
# OK Touraine LOC
# OK Chine LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Eyssette LOC

# %% [markdown]
# ## Des programmes au logiciel : rendre le code robuste et produire une Interface
#
# Le prototype est disponible sur __Pandore__ la toolbox proposée par __ObTIC__.
# https://pandore-toolbox.isir.upmc.fr/ocr_map
# <table>
#     <td style="text-align:center"><img src="../DATA/images/github.png" width="15" height="7"></td>
# <td style="text-align:center">Github :<a href="https://github.com/obtic-sorbonne/Toolbox-site/tree/nermap">https://github.com/obtic-sorbonne/Toolbox-site/tree/nermap</a>  </td>
# </table>
#
#
#
# Toutes les configuration ne fonctionnent pas encore

# %% [markdown]
# <img src="../DATA/images/prototype.png" width="500">

# %% [markdown]
# <img src="../DATA/images/EPIMETHEE_10-10-2023.png">

# %% [markdown]
# <img src="../DATA/images/EPIMETHEE_10-10-2023_MORLINCOURT.png">

# %% [markdown]
# ## Filtrage des clusters
# <table>
#     <tr>
#     <td style="text-align:center"><img src="../DATA/images/ADAM_KRAKEN_CLUSTER_AVANT00.png" width="600" height="150"></td>
#     <td style="text-align:center"><img src="../DATA/images/ADAM_KRAKEN_CLUSTER_APRES00.png" width="600" height="150"></td>
#     </tr>
#      <tr>
#     <td style="text-align:center"><h3>Avant filtage</h3></td>
#          <td style="text-align:center"><h3>Après filtrage</h3></td>
#     </tr>
# </table>
