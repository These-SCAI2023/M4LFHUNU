# %% [markdown]
# <h3>Avant de commencer procéder à l'installation : </h3>
# <br>
#     <td style="text-align:center">spaCy :<a href="https://spacy.io/">https://spacy.io/</a>  </td>
#     <br>
#     <td style="text-align:center">geopy :<a href="https://geopy.readthedocs.io/en/stable/">https://geopy.readthedocs.io/en/stable/</a>  </td>
#     <br>
#     <td style="text-align:center">seaborn :<a href="https://seaborn.pydata.org/">https://seaborn.pydata.org/</a>  </td>
#     <br>
#     <td style="text-align:center">sklearn :<a href="https://scikit-learn.org/stable/install.html">https://scikit-learn.org/stable/install.html</a>  </td>
#     <br>
#     <td style="text-align:center">pandas :<a href="https://pandas.pydata.org/">https://pandas.pydata.org/</a>  </td>
#     <br>
#     <td style="text-align:center">numpy :<a href="https://numpy.org/">https://numpy.org/</a>  </td>

# %%
##Installer spaCy une boite à outil pour le TAL qui fait entre autres de la Reconnaissance d'entités nommées
# !pip install -U pip setuptools wheel
# !pip install -U spacy
#Installer le modèle de langue qui convient 
# !python -m spacy download fr_core_news_sm
#!python -m spacy download fr_core_news_md
#!python -m spacy download fr_core_news_lg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/ceres/.local/lib/python3.12/site-packages (24.0)
# Requirement already satisfied: setuptools in /home/ceres/.local/lib/python3.12/site-packages (69.2.0)
# Requirement already satisfied: wheel in /home/ceres/.local/lib/python3.12/site-packages (0.43.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in /home/ceres/.local/lib/python3.12/site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (2.6.4)
# Requirement already satisfied: jinja2 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ceres/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/ceres/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/ceres/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ceres/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/ceres/.local/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ceres/.local/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3.12/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/ceres/.local/lib/python3.12/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib64/python3.12/site-packages (from jinja2->spacy) (2.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 29.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /home/ceres/.local/lib/python3.12/site-packages (from fr-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.6.4)
# Requirement already satisfied: jinja2 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/ceres/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ceres/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/ceres/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/ceres/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ceres/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/ceres/.local/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ceres/.local/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3.12/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.1.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/ceres/.local/lib/python3.12/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib64/python3.12/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
##Installer scikit-learn pour les calculs de similarités et le clustering
# !pip3 install -U scikit-learn
#!python3 -m pip show scikit-learn  # to see which version and where scikit-learn is installed
#!python3 -m pip freeze  # to see all packages installed in the active virtualenv
#!python3 -c "import sklearn; sklearn.show_versions()"
# Out:
# Name: scikit-learn
# Version: 1.4.1.post1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /home/ceres/.local/lib/python3.12/site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:

# %%
##Installer numpy pour les calculs de matrices dans la phase de clustering
# !pip install numpy

# %%
##Installer seaborn pour la représentation graphique
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ceres/.local/lib/python3.12/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/ceres/.local/lib/python3.12/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/ceres/.local/lib/python3.12/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ceres/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ceres/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ceres/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ceres/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ceres/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ceres/.local/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ceres/.local/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
##Installer matplotlib pour la représentation graphique
# !python -m pip install -U pip
# !python -m pip install -U matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/ceres/.local/lib/python3.12/site-packages (24.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Using cached matplotlib-3.8.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.50.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /home/ceres/.local/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.12/site-packages (from matplotlib) (10.2.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.12/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.8.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached contourpy-1.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (303 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.50.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Using cached kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.50.0 kiwisolver-1.4.5 matplotlib-3.8.3 pyparsing-3.1.2

# %%
##Installer pandas pour faire des tableaux
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Using cached pandas-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.26.0 in /home/ceres/.local/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.12/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 30.6 MB/s eta 0:00:00m eta 0:00:010:0101
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.1 pytz-2024.1 tzdata-2024.1

# %%
import glob

# %%
#La fonction qui sert à lire les textes pour tous le notebook. 
#Attention si vous souhaitez lire un autre format de fichier :csv, json, etc., elle n'est pas adéquate
def read_text(path_corpora):
        with open (path_corpora, "r", encoding="utf-8") as fichier:
            txt=fichier.read()
        return txt
    

path_corpus= "../DATA/ELTeCFRA/AIMARD_TRAPPEURS/*/*.txt"
for path in glob.glob(path_corpus):
    nom_fichier=path.split("/")[-1]
    texte=read_text(path)
    print(f"_________Titre du texte lu : {nom_fichier}__________")
    print("\n")
    print(f"Le texte lu :\n\n\n {texte[:250]}")
    print("\n")
# Out:
# _________Titre du texte lu : AIMARD_les-trappeurs_TesseractFra-PNG.txt__________
#
#
# Le texte lu :
#
#
#  PROLOGUE.
#
# LE MAUDIT.
#
# ]
# HERMOSILLO.
#
# Le voyageur qui pour la première fois débarque
# dans l'Amérique du Sud, éprouve malgré lui un
# sentiment de tristesse indéﬁnissable.
#
# En effet, l‘histoire du nouveau monde n’est qu’un
# lamentable martyrologe, dans l
#
#
# _________Titre du texte lu : AIMARD_les-trappeurs_Kraken-base.txt__________
#
#
# Le texte lu :
#
#
#  T  T
# LE MAUDII.
# HERM0SIILL0.
# Le voyageur qui pour la premiere fois debarque
# dans l'Amerique du Sud, eprouve malgre lui un
# sentiment de tristesse indefinissable.
# En effet, l'histoire du nouveau monde n'est qu'un
# lamentable martyrologe, dans lequel le
#
#
# _________Titre du texte lu : AIMARD_les-trappeurs_PP.txt__________
#
#
# Le texte lu :
#
#
#  Prologue -- Le maudit
# I -- Hermosillo
# Le voyageur qui pour la première fois débarque dans l'Amérique du Sud éprouve malgré lui un sentiment de tristesse indéfinissable.
# En effet, l'histoire du Nouveau Monde n'est qu'un lamentable martyrologe, dans

# %% [markdown]
# ## Reconnaissance d'entités nommées (REN) sur des données bruitées avec spaCy
#
# https://spacy.io/
#
# SpaCy est un outil de traitement automatique des langues qui peut également être utilisé pour la REN.
#
# Il permet de retrouver les EN accompagnées d'un libellé, ainsi que la position du caractère de début et de fin du terme identifié.
#
# Nom de lieu : LOC ;
# Nom de la personne : PERS ;
# Organisations : ORG ; ...

# %%
#Importer la boite à outil spaCy
import spacy
# chargement du modèle de langue de spaCy avec lequel vous souhaitez travailler
modele_langfr=["fr_core_news_lg","fr_core_news_md","fr_core_news_sm"]
#Vous pouvez changer le modèle de langue si vous en avez installé plusieurs : 0="fr_core_news_lg", 1="fr_core_news_md", 2="fr_core_news_sm"
modele=modele_langfr[-1]
nlp = spacy.load(modele)

# %%
# Importer le visualiseur Displacy de Spacy
from spacy import displacy

#cette boucle permet la lecture, l'analyse et l'affichage pour les différentes versions du texte
for path in glob.glob(path_corpus):
    version=path.split("/")[3]
    name_version=version.split("_")[-1]
    text=read_text(path)
    
    if "REF" in path:
        print("Reference text output :" )
        doc1 =  nlp(text[:2000])
        
    if "Kraken" in path:
        doc2 =  nlp(text[:2000])
        
    if "Tesseract" in path:
        doc3 =  nlp(text[:2000])
    
#Afficher les résultats pour la REN avec le visualiser Displacy
disp=displacy.serve(doc1,style="ent")
# Out:
# Reference text output :
# /home/ceres/.local/lib/python3.12/site-packages/spacy/displacy/__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prologue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  -- Le maudit <br>I -- Hermosillo <br>Le voyageur qui pour la première fois débarque dans
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l'Amérique
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  du Sud éprouve malgré lui un sentiment de tristesse indéfinissable. <br>En effet, l'histoire du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nouveau Monde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  n'est qu'un lamentable martyrologe, dans lequel le fanatisme et la cupidité marchent continuellement côte à côte. <br>La recherche de l'or fut l'origine de la découverte du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nouveau Monde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ; cet or une fois trouvé,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l'Amérique
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ne fut plus pour ses conquérants qu'une étape où ces avides aventuriers venaient, un poignard d'une main et un crucifix de l'autre, recueillir une ample moisson de ce métal si ardemment convoité, après quoi ils s'en retournaient dans leur patrie faire étalage de leurs richesses et provoquer par le luxe effréné qu'ils déployaient de nouvelles émigrations. <br>C'est à ce déplacement continuel qu'il faut attribuer, en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amérique
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , l'absence de ces grands monuments, sortes d'assises fondamentales de toute colonie qui s'implante dans un pays nouveau pour y perpétuer sa race. <br>Ce vaste continent, qui pendant trois siècles a été la paisible possession des
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Espagnols
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , parcourez-le aujourd'hui, c'est à peine si de loin en loin quelque ruine sans nom y rappelle leur passage, tandis que les monuments élevés, bien des siècles avant la découverte, par les
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aztèques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  et
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     les Incas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  sont encore debout dans leur majestueuse simplicité, comme un témoignage impérissable de leur présence dans la contrée et de leurs efforts vers la civilisation. <br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hélas !
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  que sont devenues aujourd'hui ces glorieuses conquêtes enviées par
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l'Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  entière, où le sang des bourreaux s'est confondu avec le sang des victimes au profit de cette autre nation si fière alors de ses vaillants capitaines, de son territoire fertile et de son commerce qui embrassait le monde entier ; le temps a marché et
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l'Amérique
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  méridionale expie à l'heure qu'il est les crimes qu'elle a fait commettre. Déchirée par des factions qui se disputent un pouvoir éphémère, opprimée par des oligarchies ruineuses, désertée par </div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
print("Kraken output : ")
displacy.serve(doc2,style="ent")
# Out:
# Kraken output :
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T  T
# LE MAUDII
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HERM0SIILL0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br>Le voyageur qui pour la premiere fois debarque<br>dans l'
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amerique du Sud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , eprouve malgre lui un<br>sentiment de tristesse indefinissable.<br>En effet, l'histoire du nouveau monde n'est qu'un<br>lamentable martyrologe, dans lequel le fanatisme<br>et la cupidite marchent continuelleent
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cte A
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# <br>cte.<br>La recherche de lor fut l'origine de la decou-<br>verte du nouveau monde; cet orune fois trouve, l'
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A-
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>merique ne fut plus pour ses conquerants qu'une<br>etape oi ces avides aventuriers venaient, un poi-<br>gnard d'une main et un crucifix de l'autre, recueillir<br>une ample moisson de ce metal si ardemment con-<br>voite, apres quoi ils s'en retournaient dans leur pa-<br>trie faire etalage de leurs richesses et provoquer<br>par le luxe effrene qu'ils deployaient de nouelles<br>emigrations.<br>LES
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TAPPEURS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# <br>C'est h ce deplacement continuel qu'il faut attri-<br>buer, en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amerique
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , l'absence de ces grands monu-<br>ments, sortes d'assises fondamentales de toute colo-<br>ie qui s'implante dans un pays nouveau pour y<br>perpetuer sa race.<br>Ce vaste continent, qui pendant trois siecles a ete<br>la paisible possession des
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Espagnols
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , parcourez-le<br>aujourd'hui, c'est a peine si de loin en loin quelque<br>ruine sans nom y rappelle leur passage, tandis que<br>les monuments eleves , bien des siecles avant la<br>decouverte, par les
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Azteques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     les Incas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  sont encore<br>debout dans leur majestueuse simplicite, comme un<br>temoignage imperissable de leur presence dans la<br>contree et de leurs elforts vers la civilisation.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Helasl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  que sont devenues aujourd'hui ces glo-<br>rieuses conquetes enviees par l'Europe entiere, oi<br>le sang des bourreaux s'est confondu avec le sang<br>des victimes au profit de cette autre nation si fiere<br>alors de ses vaillanls capitaines, de son territoire<br>fertile et de son commerce qui embrassait le monde<br>entier; le temps a marche et l'
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amerique meridionale
# expie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  a l'heure qu'il est les crimes qu'elle a fait<br>commettre. Dechiree par des factions qui se dispu-<br>tent un pouvoir ephemere, opprimee par des oligar-<br>chies ruineuses, de</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
print("Tesseractfr text output :" )
displacy.serve(doc3,style="ent")
# Out:
# Tesseractfr text output :
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROLOGUE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br><br>LE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MAUDIT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br><br>]<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HERMOSILLO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .<br><br>Le voyageur qui pour la première fois débarque<br>dans
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l'Amérique
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  du Sud, éprouve malgré lui un<br>sentiment de tristesse indéﬁnissable.<br><br>En effet, l‘histoire du nouveau monde
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     n’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# est qu’un<br>lamentable martyrologe, dans lequel le fanatisme<br>et la cupidité marchent continuellement côte à<br>côte.<br><br>La recherche de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# or fut
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# origine de la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     décou—
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>Verte du nouveau monde; cet or une fois trouvé,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l’A—
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>mérique ne fut plus pour ses conquérants qu’une<br>étape où ces avides aventuriers venaient, un poi—<br>gnard d’une main et un cruciﬁx de l‘autre, recueillir<br>une ample moisson de ce métal si ardemment con—<br>voité, après quoi ils
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     s’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# en retournaient dans leur pa-<br>trie faire étalage de leurs richesses et provoquer<br>par le luxe
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eﬁ”réné
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  qu’ils déployaient de nouvelles<br>émigrations.<br><br>4 ' nas
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     THAPPEURS
#
# C’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# est à ce déplacement continue]
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     qu’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# il faut attri-<br>buer, en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amérique
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , l'absence de ces grands
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monu—
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# <br>ments, sortes
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     d’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# assises fondamentales de toute
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     colo—
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# <br>nie qui
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     s’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# implante dans un pays nouveau pour y<br>perpétuer sa race.<br><br>Ce vaste continent, qui pendant trois siècles a été<br>la paisible possession des
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Espagnols
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , parcourez-le<br>aujourd’hui,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     c’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# est a peine si de loin en loin quelque<br>ruine sans nom y rappelle leur passage, tandis que<br>les monuments élevés , bien des siècles avant la<br>découverte, par les
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aztèques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ## Récupérer les résultats de REN dans plusieurs formats :
#
#  -  sous forme de tableau avec pandas
#  - sous forme de tableau csv
#  - au format json

# %%
import pandas as pd
from IPython.display import display
import json

# %%
#stockage des données dans un format json pour une réutilisation des données
def stocker(chemin, contenu):
    w =open(chemin, "w")
    w.write(json.dumps(contenu , indent = 2))
    w.close()
    # print(chemin)
    
    return chemin

# %%
for path in glob.glob(path_corpus):

    dict_ent={}
    liste_ent=[]
    liste_label=[]
    liste_contxt_droit=[]
    liste_contxt_gauche=[]
    auteur=path.split("/")[3]
    version=path.split("/")[-2]
    version=version.split("_")[-1]
    print("------------",auteur,version)

    
    text=read_text(path)
    
    
    doc = nlp(text)

    for ent in doc.ents:
        if ent.label_=="LOC":### Retrieve spacial entities only
            liste_ent.append(ent.text)
            liste_label.append(ent.label_)
            liste_contxt_gauche.append(text[ent.start_char-15:ent.start_char])

            liste_contxt_droit.append(text[ent.end_char:ent.end_char+15])
        
    dict_ent["Entite"]=liste_ent
    dict_ent["Label"]=liste_label
    dict_ent["liste_contxt_gauche"]=liste_contxt_gauche
    dict_ent["liste_contxt_droit"]=liste_contxt_droit
    
    data_tab = pd.DataFrame(dict_ent)
    
    display(data_tab)  
    data_tab.to_csv(f"../DATA/ELTeCfra{version}.csv", sep=";")
    
    
    #stockage des EN concatenées pour la phase d'evaluation. 
    # La concatenation des En permets une meilleure comparaison ?
    list_concat=[]
    for i in liste_ent:
        
        
        i_replace = i.replace(" ", "")
        
        list_concat.append(i_replace)
    stocker("%s-%s-concat.json"%(path,modele),list_concat)
# Out:
# ------------ AIMARD_TRAPPEURS TesseractFra-PNG
#                           Entite Label  liste_contxt_gauche liste_contxt_droit
# 0                     l'Amérique   LOC      débarque\ndans      du Sud, éprouv
# 1                             l’   LOC      a recherche de     or fut l’origin
# 2                             l’   LOC      he de l’or fut     origine de la d
# 3                            qu’   LOC      ment continue]    il faut attri-\n
# 4                       Amérique   LOC     ttri-\nbuer, en     , l'absence de
# ...                          ...   ...                  ...                ...
# 2104                          gr   LOC      du Roi. 2 vo.\n    . in-8° .......
# 2105                        in-8   LOC     Roi. 2 vo.\ngr.     ° .............
# 2106  Imprimerie Êiinins‘r Maven   LOC   m—8 15i .\n\n \n\n    . 3. rue de I‘A
# 2107                rue de I‘Ahl   LOC      ns‘r Maven. 3.    :ave. %: Parts\n
# 2108                       Parts   LOC       I‘Ahl:ave. %:                \n\n
#
# [2109 rows x 4 columns]
# ------------ AIMARD_TRAPPEURS kraken
#                 Entite Label liste_contxt_gauche liste_contxt_droit
# 0      Amerique du Sud   LOC    ebarque\ndans l'    , eprouve malgr
# 1                cte A   LOC     continuelleent   \ncte.\nLa recher
# 2             Amerique   LOC    ttri-\nbuer, en     , l'absence de
# 3            Espagnols   LOC     possession des    , parcourez-le\n
# 4             Azteques   LOC     verte, par les      et les Incas s
# ..                 ...   ...                 ...                ...
# 963                Cne   LOC      Uno Ambsad en     . ] vrdioN iiin
# 964                wLL   LOC    ni.g(\n.. 5r. ]     . La Guere des
# 965  Guere des Psysans   LOC      5r. ] wLL. La    . In-1. 5f, i\nI
# 966    rue de l'Ahhaye   LOC     nNRST MYER. 3,           , i Prs\n
# 967            i Prs\n   LOC     e de l'Ahhaye,
#
# [968 rows x 4 columns]
# ------------ AIMARD_TRAPPEURS REF
#            Entite Label liste_contxt_gauche liste_contxt_droit
# 0        Prologue   LOC                        -- Le maudit \n
# 1      l'Amérique   LOC      débarque dans      du Sud éprouve
# 2      l'Amérique   LOC     e fois trouvé,      ne fut plus po
# 3        Amérique   LOC      attribuer, en     , l'absence de
# 4       Espagnols   LOC     possession des     , parcourez-le
# ...           ...   ...                 ...                ...
# 998       Guaymas   LOC      m'embarquer à      comme j'en ava
# 999     Apacheria   LOC     ursion dans l'     , excursion pen
# 1000  tercushenan   LOC     rtwwaay winnin     , cawween kitch
# 1001      Indiens   LOC     s discours des    . \n1  Toute cet
# 1002    Apacheria   LOC     ssisté dans l'      à une exécutio
#
# [1003 rows x 4 columns]

# %% [markdown]
# # Clustering avec un algortihme d'affinité de propagation
#
#  - **Pas de besoin** de déterminer le **nombre de clusters** attendus
#  - Les clusters sont calculés avec la métrique **cosinus**
#  - en **bigramme** et **trigramme de caractères**.

# %%
import numpy as np
import sklearn
from sklearn.metrics import DistanceMetric
#from sklearn.neighbors import DistanceMetric
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import AffinityPropagation
from collections import OrderedDict

# %%
#Lire les fichiers json stockés à l'étape suivante
def read_json (chemin):
    with open(chemin) as json_data: 
        data =json.load(json_data)
    return data
    
def nomfichier(chemin):
    nomfich= chemin.split("/")[-1]
    nomfich= nomfich.split(".")
    nomfich= ("_").join([nomfich[0],nomfich[1]])
    return nomfich
    

def stocker(chemin,contenu):                                                   
    w=open(chemin,"w")                                                         
    w.write(json.dumps(contenu, indent=2))                                     
    w.close()

# %%
path_copora = "../DATA/ELTeCFRA/AIMARD_TRAPPEURS/*"

for subcorpus in glob.glob(path_copora):
    print("SUBCORPUS***",subcorpus)
    liste_nom_fichier =[]
    for path in glob.glob("%s/*concat.json"%subcorpus):
        print("PATH*****",path)
        
        nom_fichier = nomfichier(path)
     #   print(nom_fichier)
        liste=read_json(path)  
       # print(liste)        
#### FREQUENCE ########
        
        dic_mots={}
        i=0
    
        
        for mot in liste: 
            
            if mot not in dic_mots:
                dic_mots[mot] = 1
            else:
                dic_mots[mot] += 1        
        i += 1
        #    print(dic_mots)
        new_d = OrderedDict(sorted(dic_mots.items(), key=lambda t: t[0]))
        
#        print(new_d)
        freq=len(dic_mots.keys())      
#### VECTORISATION

        Set_00 = set(liste)
        #print(Set_00)
        Liste_00 = list(Set_00)
        dic_output = {}
        liste_words=[]
        matrice=[]
        #print(Liste_00)
        
        for l in Liste_00:
            if len(l)!=1:
                liste_words.append(l)

        try:
            words = np.asarray(liste_words) #So that indexing with a list will work
            for w in words:
                liste_vecteur=[]
            
                    
                for w2 in words:
                
                        V = CountVectorizer(ngram_range=(2,3), analyzer='char') 
                        X = V.fit_transform([w,w2]).toarray()
                        distance_tab1=sklearn.metrics.pairwise.cosine_distances(X) # Distance avec cosinus            
                        liste_vecteur.append(distance_tab1[0][1])
                    
                        #print("liste_vecteur",liste_vecteur)
            
            
            #  
                matrice.append(liste_vecteur)
            matrice_def=-1*np.array(matrice)
            #print(matrice)
            
    ##### CLUSTER
                  
            affprop = AffinityPropagation(affinity="precomputed", damping= 0.5, random_state = None) 
    
            affprop.fit(matrice_def)
            for cluster_id in np.unique(affprop.labels_):
                exemplar = words[affprop.cluster_centers_indices_[cluster_id]]
                cluster = np.unique(words[np.nonzero(affprop.labels_==cluster_id)])
                cluster_str = ", ".join(cluster)
                cluster_list = cluster_str.split(", ")
            #                print(" - *%s:* %s" % (exemplar, cluster_str))                
                Id = "ID "+str(i)
                for cle, dic in new_d.items(): 
                    if cle == exemplar:
                        dic_output[Id] ={}
                        dic_output[Id]["Centroïde"] = exemplar
                        dic_output[Id]["Freq. centroide"] = dic
                        dic_output[Id]["Termes"] = cluster_list
                
                i=i+1
            #print(dic_output)
            data_cluster = pd.DataFrame(dic_output)
            display(data_cluster) 
        
            stocker("%s/%s_cluster-consinus-2-3-clean.json"%(subcorpus,nom_fichier),dic_output)

        except :        
            print("**********Non OK***********", path)

    
            liste_nom_fichier.append(path)
            stocker("%s/fichier_non_cluster.json"%subcorpus, liste_nom_fichier)
            
            continue
# Out:
# SUBCORPUS*** ../DATA/ELTeCFRA/AIMARD_TRAPPEURS/AIMARD-TRAPPEURS_TesseractFra-PNG
# PATH***** ../DATA/ELTeCFRA/AIMARD_TRAPPEURS/AIMARD-TRAPPEURS_TesseractFra-PNG/AIMARD_les-trappeurs_TesseractFra-PNG.txt-fr_core_news_sm-concat.json
#                                    ID 1                          ID 2  \
# Centroïde                         peut—                    Gambusinos
# Freq. centroide                       3                             2
# Termes           [b0ut, peuple—, peut—]  [Gambusinos, Gambusîno, Oak]
#
#                                                               ID 3  \
# Centroïde                                                    cou—-
# Freq. centroide                                                  1
# Termes           [beau—, couar—, coup—d’œil, cou—-, décou—, par...
#
#                                                              ID 4  \
# Centroïde                                                    Vais
# Freq. centroide                                                 2
# Termes           [Pouvais, Savais-tu, Va, Vaincue, Vais, devais—]
#
#                                                  ID 5  \
# Centroïde                                        J’ai
# Freq. centroide                                     1
# Termes           [-—J’, J’ai, j’, j’ail’, l’aioiruni]
#
#                                                               ID 6  \
# Centroïde                                              Américaines
# Freq. centroide                                                  1
# Termes           [Américaines, Américains, Cric, G3PITAINE, cam...
#
#                                                               ID 7  \
# Centroïde                                           TRAPPEUBS\n\n—
# Freq. centroide                                                  1
# Termes           [TBAPPEUPtS, TBAPPEURS\n\n—, TRAPPEUBS\n\n, TR...
#
#                                         ID 8                             ID 9  \
# Centroïde                           MoyenAge                         immédia—
# Freq. centroide                            1                                2
# Termes           [MavenAge, Moyen, MoyenAge]  [immédiate—, immédia—, mée, t’]
#
#                                                       ID 10  ...  \
# Centroïde                                               ger  ...
# Freq. centroide                                           2  ...
# Termes           [Régencesd’Alger, ger, gers, songerais-tu]  ...
#
#                                                             ID 123  \
# Centroïde                                                Veillerai
# Freq. centroide                                                  1
# Termes           [Caballeros, Reculerais, Serait, Veillerai, Vi...
#
#                                                             ID 124  \
# Centroïde                                                     Sins
# Freq. centroide                                                  1
# Termes           [Sins, coquins, insen—, insis—, insou—, lesInc...
#
#                                                     ID 125  \
# Centroïde                                               L’
# Freq. centroide                                         14
# Termes           [Al’, Enﬁnl’, Luzl’, L’, TllAl’, l’, l’-]
#
#                                                             ID 126  \
# Centroïde                                        continual’inconnu
# Freq. centroide                                                  1
# Termes           [Aminuit, Continuez, Convaincu, contem—, conti...
#
#                                                         ID 127 ID 128  \
# Centroïde                                                suis—     J'
# Freq. centroide                                              1      1
# Termes           [SBUI‘S, pis—-, ruis—, réjouis—, su1s, suis—]   [J']
#
#                                                  ID 129  \
# Centroïde                                         meil—
# Freq. centroide                                       1
# Termes           [bouil—, bril—, feuil—, meil—, oreil—]
#
#                                 ID 130  \
# Centroïde                         ——C’
# Freq. centroide                      8
# Termes           [-—C’, C’, V——, ——C’]
#
#                                                     ID 131  \
# Centroïde                                               Ou
# Freq. centroide                                          1
# Termes           [Cordoue, Guadeloupe, Ou, douce—, voulez]
#
#                                                    ID 132
# Centroïde                                   Confédération
# Freq. centroide                                         1
# Termes           [Confédération, Malédiction, confédéra—]
#
# [3 rows x 132 columns]
# SUBCORPUS*** ../DATA/ELTeCFRA/AIMARD_TRAPPEURS/AIMARD-TRAPPEURS_kraken
# PATH***** ../DATA/ELTeCFRA/AIMARD_TRAPPEURS/AIMARD-TRAPPEURS_kraken/AIMARD_les-trappeurs_Kraken-base.txt-fr_core_news_sm-concat.json
#                                                               ID 1  \
# Centroïde                                                  Iateros
# Freq. centroide                                                  1
# Termes           [Hatez, I09, Iateros, Jupiter, Lanceros, Plate...
#
#                                                               ID 2  \
# Centroïde                                                   Caches
# Freq. centroide                                                  1
# Termes           [Apaches, Caches, Chacun, Nhesitez, Tachez, cher]
#
#                                                               ID 3  \
# Centroïde                                                 J'aurais
# Freq. centroide                                                  2
# Termes           [--Reculerais-tu, J'aimerais, J'aurais, J'aura...
#
#                              ID 4                  ID 5  \
# Centroïde                  voulez                   Luz
# Freq. centroide                 4                     7
# Termes           [Voulez, voulez]  [A6, Iuz, Lnuz, Luz]
#
#                                                               ID 6  \
# Centroïde                                          rayedevermillon
# Freq. centroide                                                  1
# Termes           [Confederation, Hermosillo, ayec, rayedevermil...
#
#                                                          ID 7  \
# Centroïde                                            inquiete
# Freq. centroide                                             2
# Termes           [Lapluie, Societ, coquins, foruie, inquiete]
#
#                                                               ID 8  \
# Centroïde                                                   Indien
# Freq. centroide                                                 16
# Termes           [Dienu, Inde, Indens, Indien, Indiennes, Indie...
#
#                                                               ID 9  \
# Centroïde                                                     bles
# Freq. centroide                                                  1
# Termes           [LES5, LesDelawvares, Naples, Sacrebleui, Tous...
#
#                                                              ID 10  ...  \
# Centroïde                                              TRAPPEUIS\n  ...
# Freq. centroide                                                  1  ...
# Termes           [IRAPPEUIS\n, Rapportez, TRAPPEUIS\n, TRAPPEUI...  ...
#
#                                             ID 75  \
# Centroïde                                   Soyez
# Freq. centroide                                 4
# Termes           [Moyen, Soyez, Voyez, soyezsage]
#
#                                                              ID 76  \
# Centroïde                                                Comanches
# Freq. centroide                                                 11
# Termes           [CG', Comanche, Comanches, Comanchessont, Homm...
#
#                                           ID 77  \
# Centroïde                           -iiiiiii.ii
# Freq. centroide                               1
# Termes           [-iiiiiii.ii, Niian, iii''iii]
#
#                                                              ID 78  \
# Centroïde                                               Providence
# Freq. centroide                                                  1
# Termes           [LaProvidence, Linproiisioro, Providence, Trnc...
#
#                                                              ID 79  \
# Centroïde                                                  Mexique
# Freq. centroide                                                  4
# Termes           [-Que, Azteques, Mexique, Mlexique, Pacifique,...
#
#                                                         ID 80  \
# Centroïde                                              z::::z
# Freq. centroide                                             1
# Termes           [EE.::1EciGZ, trc::r, z::::-, z::::z, z::DE]
#
#                                     ID 81                      ID 82  \
# Centroïde                            .--c                       Voil
# Freq. centroide                         1                          1
# Termes           [.--EeA20, .--c, .:-.--]  [-Amoil, Voil, Voilh, vo]
#
#                                                          ID 83  \
# Centroïde                                                 Elan
# Freq. centroide                                             20
# Termes           [Elan, IlisoiaelaHoyiu, Llan, el, melancolie]
#
#                                         ID 84
# Centroïde                             Figurez
# Freq. centroide                             1
# Termes           [Figurez, Rassurez, figurez]
#
# [3 rows x 84 columns]
# SUBCORPUS*** ../DATA/ELTeCFRA/AIMARD_TRAPPEURS/REF
# PATH***** ../DATA/ELTeCFRA/AIMARD_TRAPPEURS/REF/AIMARD_les-trappeurs_PP.txt-fr_core_news_sm-concat.json
#                                                               ID 1  \
# Centroïde                                                       us
# Freq. centroide                                                  1
# Termes           [Eusébio, Poussé, Russe, SanAgustin, Syracuse,...
#
#                                                           ID 2  \
# Centroïde                                         DoñaJesusita
# Freq. centroide                                              6
# Termes           [DoñaJesusita, DoñaLuz, Señorita, – Jesusita]
#
#                                    ID 3  \
# Centroïde                    – Diable !
# Freq. centroide                       1
# Termes           [– Diable, – Diable !]
#
#                                                               ID 4  \
# Centroïde                                                 lesoleil
# Freq. centroide                                                  3
# Termes           [Conseille, LeSoleil, Lesoleil, Soleil, besogn...
#
#                                                               ID 5  \
# Centroïde                                                       –
# Freq. centroide                                                  5
# Termes           [– , – Holà, – Kennedy, – Non, – Oui, – Pardie...
#
#                                                 ID 6  \
# Centroïde                                    Vaincue
# Freq. centroide                                    1
# Termes           [Certain, Convaincu, Vaincue, Vais]
#
#                                                               ID 7  \
# Centroïde                                                   Sonora
# Freq. centroide                                                  3
# Termes           [Bison, Confédération, Sonora, duNord, ÉtatdeS...
#
#                                            ID 8  \
# Centroïde                          NègreJupiter
# Freq. centroide                               1
# Termes           [Jupiter, Nègre, NègreJupiter]
#
#                                                           ID 9  \
# Centroïde                                                Viens
# Freq. centroide                                              1
# Termes           [Chiens, Mocksens, Pensant, Tiens, VI, Viens]
#
#                                                              ID 10  ...  \
# Centroïde                                                    Allez  ...
# Freq. centroide                                                  4  ...
# Termes           [Allez, Allons, Essayez, Parlez, alluma, bois-...  ...
#
#                                          ID 52  \
# Centroïde                             Répondez
# Freq. centroide                              2
# Termes           [Rendez, Répondez, répondrez]
#
#                                                              ID 53  \
# Centroïde                                              Assiniboins
# Freq. centroide                                                  1
# Termes           [Assiniboins, Ciboto, Finissons-en, Linnée, Mi...
#
#                                   ID 54                           ID 55  \
# Centroïde                          Rome                        Canadien
# Freq. centroide                       1                              18
# Termes           [Prompt, Rome, Sommes]  [Canadien, Canadienne, Panama]
#
#                                                              ID 56  \
# Centroïde                                                    Hâtez
# Freq. centroide                                                  1
# Termes           [Arrêtez, Hâte-toi, Hâtez, Hâtons, Mettez, Oua...
#
#                                                        ID 57  \
# Centroïde                                             Europe
# Freq. centroide                                            2
# Termes           [Créateur, Europe, l'Europe, vieilleEurope]
#
#                                                              ID 58  \
# Centroïde                                               – Tuez-moi
# Freq. centroide                                                  1
# Termes           [Moi-même, épargnez-les-moi, – Tue-moi, – Tuez...
#
#                                                           ID 59  \
# Centroïde                                               Tripoli
# Freq. centroide                                               1
# Termes           [Acropolis, Tripoli, Trêve, golfedeCalifornie]
#
#                                       ID 60  \
# Centroïde                          Bourreau
# Freq. centroide                           1
# Termes           [Bonjour, Bourreau, Peaux]
#
#                                                ID 61
# Centroïde                                  Apacheria
# Freq. centroide                                    2
# Termes           [Apacheria, Apaches, Caché, – Cher]
#
# [3 rows x 61 columns]

# %%
import matplotlib.pyplot as plt
import csv
import seaborn as sns
sns.set(style="whitegrid")


def nomfichier(chemin):
    nomfich= chemin.split("/")[-1]
    nomfich= nomfich.split(".")
    nomfich= ("_").join([nomfich[0]])
    return nomfich

centro=[]
cluster=[]
i=0

#iy=1
#centro=[]
#cluster=[]
liste_resultat=[]

file_path="../DATA/SPACY_ANNOT/DAUDET/DAUDET_petit-chose_Kraken-base_txt_lg_spacy_cluster-cosinus-2-3_ANNOT.csv"

with open(file_path, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=';', quotechar=' ')
    next(spamreader)
    
    for row in spamreader:
#        print(row)
        liste_resultat.append(row)

for liste in liste_resultat:
 

    if liste[-1]=="":
        centro.append([liste[1],liste[-2]])
    else:
        cluster.append([liste[1],liste[2],liste[-1]])
            
#print(cluster)
for cl in cluster:
#            for centr in centro:
#                if cl[0]==centr[0]:
#                    centr.append(cl)
 
    if cl[0]==centro[i][0]:

        centro[i].append(cl)
#        print("Pareil",cl[0],centro[i][0])

    else:
#        #        print("*************PAS Pareil",cl[0],centro[i][0])
        i=i+1
        centro[i].append(cl)

        
tableau={}
liste_label_centro=[]
liste_label_cluster=[]
liste_statut_centro=[]
liste_statut_cluster=[]
liste_ix=[]
liste_resultat_dist2=[]
liste_lower=[]
ix=0
icl=0

liste_resultat_dist_low=[]

for ce in centro:   
#    ix+=10
    ix=(ix+100)-ix%100
    icl=0
    for j in ce[2:]:
        
        if ce[0]==j[1]:
            liste_ix.append(ix)
        else:       
            icl=icl+50
            liste_ix.append(ix+icl)

            
        V = CountVectorizer(ngram_range=(2,3), analyzer='char')
        #lower case =True par défaut
        X = V.fit_transform([j[0],j[1]]).toarray()
       
        ### Distance Cosinus
        distance_tab1=sklearn.metrics.pairwise.cosine_distances(X) 
        liste_resultat_dist2.append(distance_tab1[0][1])
 
         
        liste_statut_centro.append(ce[1])
        liste_label_centro.append(ce[0])
        liste_label_cluster.append(j[1])
        liste_statut_cluster.append(j[2])
    ix+=icl
    #print(liste_ix)  
    
coord_zip=zip(liste_resultat_dist2,liste_ix) 
#print (list(test_zip))
coord=[]
coord_cl=[]
for ind in list(coord_zip):
    coord_cl.append(ind)
#    print(ind[0])
    if ind[0]==0.0:
        coord.append(ind)
#        print(ind)

liste_centr=[]
for ce in centro: 
    liste_centr.append(ce[0]) 

liste_clus=[]
for cl in cluster:
    liste_clus.append(cl[1])
#print(liste_clus)
    
groups={}

for l,c in zip(liste_centr,coord): 
    groups[l]={}
    groups[l]=c
    
groups_cl={}
for lc,cc in zip(liste_clus,coord_cl): 
    groups_cl[lc]={}
    groups_cl[lc]=cc


tableau["label_centro"]=liste_label_centro
tableau["label_cluster"]=liste_label_cluster
tableau["Statut_cluster"]=liste_statut_cluster
tableau["Statut_centro"]=liste_statut_centro
tableau["Distances cosinus"]=liste_resultat_dist2
tableau["Centroïdes"]=liste_ix
        
      
data = pd.DataFrame(tableau)

data.head()

#y_min=0
#y_max=1000

facet2=sns.relplot(data=data, x="Distances cosinus", y="Centroïdes", hue="label_centro", style="Statut_cluster",s=40)
facet2.set_yticklabels([])
#Permet de changer la taille de la figure
plt.gcf().set_size_inches(25, 25)

for key, values in groups_cl.items():            
        plt.annotate(key,values, horizontalalignment='right', verticalalignment='top',
                     size=5, weight='bold')           

        #La figure est stockée au bout du chemin suivant 
plt.savefig("../DATA/OUTPUT_CLUSTER/DAUDET_petit-chose_Kraken-base_lg_spacy_cluster-cosinus-2-3_ANNOT_ok.png",dpi=300, bbox_inches="tight")

# %% [markdown]
# # Représenter les résultats sur une carte ?
# <h3>Cas d'usage</h3>
# <h3>Un collègue chercheur en Lettres a besoin d'un programme qui récupère sur 800 romans OCRisés :
#     <br>
#  - les entités nommées,
#     <br>
#  - les contextes gauches et droits,
#     <br>
#  - différentes métadonnées.
#     <br>
#     Il veut récupérer toutes les EN, mais souhaite que les EN LOC soient **géolocalisées**.</h3>
#
# Problèmes 1 : Le géocodeur ne **trouve pas toujours** de géolocalisation pour une EN.
#
# Commentaires :
#  - le géocodeur sert de filtre : il ne s'agit pas d'une EN, c'est du **bruit**,
#  - il n'y en a **pas beaucoup** par fichier.
#       - **Solution : Complétion à la main dans un fichier csv.**
#  - il y en a beaucoup trop il faut améliorer le programme de geocoding ?
#
# Problèmes 2 : Le géocodeur **trouve** la géolocalisation pour une EN LOC, qui en fait est du bruit :
# - **c'est vrai il y en a, mais c'est toujours moins long que de corriger tous le texte à la main ?**
#     - **Solution** : changement de label et supression de la localisation à la main dans un fichier csv.

# %%
import csv
import glob
import spacy
from geopy.geocoders import Nominatim
from collections import OrderedDict



def lire_fichier (chemin):
    f = open(chemin , encoding = 'utf−8')
    chaine = f.read ()
    f.close ()
    return chaine


def titre_auteur(chemin):
    nomfich= chemin.split("/")[-1]
    nomfich= nomfich.split(".")[0]
    nomfich= nomfich.split("_")
    # nomfich= nomfich.upper()
    # nomfich= ("_").join([nomfich[0]])
    return nomfich

## MAIN
y=0
geo_flag=0

path_corpora = "../DATA/ELTeCFRA/DAUDET/DAUDET_TesseractFra-PNG/*.txt"

list_resultats=[]
liste_res=[]


nlp = spacy.load("fr_core_news_lg")
nlp.max_length = 3508822 
for path in glob.glob(path_corpora):
    print(path)
    titreauteur=titre_auteur(path)   
    texte = lire_fichier(path)
    text=nlp(texte)       
    liste_tok=[]
    for token in text:
        liste_tok.append(token.text)
    
    for ent in text.ents:
        list_resultats.append([titreauteur[0],titreauteur[1],len(liste_tok),ent.text, ent.start_char, ent.end_char, ent.label_,texte[ent.start_char-200:ent.start_char],texte[ent.end_char:ent.end_char+200]])
        

for i in list_resultats:

    start_caract = i[4]
    end_caract =i[5]
    # print(start_caract,end_caract)
    if i[-3]=="LOC":
        # print(i)
        ## Geolocalisation avec Nominatim
        try:
            res = i[3].replace("\n\n", "")
            geolocator = Nominatim(user_agent="htpss")
            location = geolocator.geocode(i[3],timeout=30)
            liste_res.append([i[0],i[1],"année ",i[2],i[3],i[-3],location.latitude ,location.longitude,i[4],i[5],i[-2],i[-1]])
            print("OK",i[3],i[-3])
        except:
            ## On gère les exceptions : il y a une EN labelisée LOC mais pas de geoloc.
                print("!!! Pas de localisation pour le LOC : ", i[3])
                liste_res.append([i[0],i[1]," année",i[2],i[3],i[-3],"None","None",i[4],i[5],i[-2],i[-1]])
                continue
    else:
        liste_res.append([i[0],i[1],"année ",i[2],i[3],i[-3],"None ","None",i[4],i[5],i[-2],i[-1]])
        #print("Entité label autre :",i[3],",",i[-3])

## Stockage au format .csv  
## Utilisation dans GoogleMymap : paramétrage du delimiter avec une "," à la place du ";"
with open("../DATA/OUTPUT_CSV/toto.csv", 'w', newline='', encoding = 'utf−8') as csvfile:
            spamwriter = csv.writer(csvfile, delimiter=';', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            spamwriter.writerow(["auteur"]+["titre"]+["annee"]+["nb_tokens_texte"]+["Entite"] + ["Label"]+["latitude"]+["longitude"]+["caractere_debut"]+["caractere_fin"]+["contexte_gauche"]+["contexte_droit"])  
            for res in liste_res:
                spamwriter.writerow(res)
# Out:
# ../DATA/ELTeCFRA/DAUDET/DAUDET_TesseractFra-PNG/DAUDET_petit-chose_TesseractFra-PNG.txt
# OK Languedoc LOC
# OK Midi LOC
# OK Carmélites LOC
# OK romains LOC
# OK Bibliothèque nationale de France LOC
# OK Eyssette LOC
# OK Annou LOC
# OK Marseille LOC
# OK Marseille LOC
# OK Marseille LOC
# OK Annou LOC
# OK Eyssette LOC
# OK Annou LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Annou LOC
# OK Annou LOC
# OK m'’appelais LOC
# OK Océan LOC
# OK vages LOC
# OK Eyssette LOC
# OK Récollets LOC
# OK Récollets LOC
# OK Vendredi LOC
# OK Î LOC
# OK Lyon LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Annou LOC
# OK Beaucaire LOC
# OK Annou LOC
# OK Lyon LOC
# OK le Rhône LOC
# OK Montélimart LOC
# OK Le Rhône LOC
# OK Midi LOC
# OK du Nord LOC
# OK Lyon LOC
# OK Lyon LOC
# !!! Pas de localisation pour le LOC :  Confusément
# OK Annou LOC
# OK Annou LOC
# !!! Pas de localisation pour le LOC :  Pécaiïre
# OK Annou LOC
# OK Lyon LOC
# OK Annou LOC
# OK Rhône LOC
# OK Midi LOC
# OK Perrache LOC
# OK Eyssette LOC
# OK Midi LOC
# OK Midi LOC
# OK Annou LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Saint-Nizier LOC
# OK Saint-
# Nizier LOC
# OK suisse LOC
# OK Midi LOC
# OK collège de Lyon LOC
# OK Lyon LOC
# OK A TRUE LOC
# !!! Pas de localisation pour le LOC :  Î as {
#
# Ps
#
# A ii
#
# D
# OK place des
# Terreaux LOC
# OK rue Lanterne LOC
# OK Saint-
# Nizier LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK croisée LOC
# OK Ë LOC
# OK Lyon LOC
# OK Eyssette LOC
# OK Saint-Nizier LOC
# OK Midi LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Midi LOC
# OK Lyon LOC
# OK pagna LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Montélimart LOC
# OK Annou LOC
# !!! Pas de localisation pour le LOC :  Mne Evyssette
# OK Sois LOC
# OK Lyon LOC
# OK là-bas LOC
# OK Rhône LOC
# OK Vienne LOC
# OK Montélimart LOC
# OK Eyssette LOC
# OK Eyssette LOC
# OK Annou LOC
# OK Annou LOC
# OK Annou LOC
# OK Eyssette LOC
# OK Annou LOC
# !!! Pas de localisation pour le LOC :  Château-
# Neuf-des-Papes
# OK Annou LOC
# OK Annou LOC
# OK vieille Fe LOC
# OK Annou LOC
# OK Lyon LOC
# OK rue Lanterne LOC
# OK Annou LOC
# OK Petit Chose LOC
# OK Angleterre LOC
# OK Carmélites LOC
# OK Cévennes LOC
# OK Ser- LOC
# OK TA LOC
# OK tâtons LOC
# OK Sarlande LOC
# OK Afrique LOC
# OK Eyssette LOC
# OK Serrières LOC
# OK Serrières LOC
# OK Sarlande LOC
# OK Serrières LOC
# OK Lyon LOC
# OK Serrières LOC
# OK Est LOC
# OK Eyssette LOC
# OK Frinc LOC
# !!! Pas de localisation pour le LOC :  portier Cassagne
# OK Arabes LOC
# OK café Barbette LOC
# OK Eyssette LOC
# OK la Prairie LOC
# !!! Pas de localisation pour le LOC :  m'’invitait
# OK la Prairie LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK la Prairie LOC
# OK collège de Lyon LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban!. LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Prairie LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK Bamban LOC
# OK ER LOC
# OK TES
#
#  LOC
# OK Cévennes LOC
# OK Bouzanquet LOC
# OK Eyssette LOC
# OK Sarlande LOC
# OK Eyssette LOC
# OK Vieux-Collège LOC
# OK califourchon LOC
# OK Est LOC
# OK Est LOC
# OK Place! LOC
# OK terre LOC
# OK Frinc LOC
# OK Est LOC
# OK Est LOC
# OK Eyssette LOC
# OK Cévennes LOC
# OK Cévennes LOC
# !!! Pas de localisation pour le LOC :  65
#
# Sd
# OK Horreur!. LOC
# !!! Pas de localisation pour le LOC :  collège cèlèbre la saint Théophile
# OK Limoux LOC
# OK LL Sd LOC
# OK la Prairie LOC
# OK Limoux LOC
# OK Frinc LOC
# OK Saint-Théophile LOC
# OK kss!. LOC
# OK kss!. LOC
# OK Saint-Théophile LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Sarlandais LOC
# OK Sarlande LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK TE LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Petit-Cercle LOC
# OK Grand-Cercle LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK la Prairie LOC
# OK Evêché LOC
# OK gardes-du-corps LOC
# OK café Barbette LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Paris LOC
# OK Ê LOC
# OK Î LOC
# OK Fanfan-la-Tulipe LOC
# OK Est LOC
# OK Paris LOC
# OK È LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK Lyon LOC
# OK Saint-Nizier LOC
# OK Providence LOC
# OK Paris LOC
# OK Sarlande LOC
# OK Bretagne LOC
# OK d’Espagne LOC
# OK Quartier Latin LOC
# OK Quartier
# Latin! LOC
# OK Est LOC
# OK OR
#
# 84 LE PETIT LOC
# OK tournai LOC
# OK Sarlande LOC
# !!! Pas de localisation pour le LOC :  m'’effraya
# OK Paris LOC
# OK Paris LOC
# OK la Prairie LOC
# OK la Prairie LOC
# OK Sarlande LOC
# OK la Prairie LOC
# OK la Prairie LOC
# OK Paris LOC
# OK la Prairie LOC
# OK TE LOC
# OK Eyssette LOC
# OK Sarlande LOC
# OK Sarlande LOC
# OK Eyssette LOC
# OK rue Bonaparte LOC
# OK Paris LOC
# !!! Pas de localisation pour le LOC :  FER 95
#
# St dd
# OK Paris LOC
# OK Paris LOC
# OK Eyssette LOC
# OK Est LOC
# OK Eyssette LOC
# !!! Pas de localisation pour le LOC :  ILE
#
# 2e ee 2er
# OK place d’Armes LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Barbette!. LOC
# OK Sonne LOC
# OK Paris LOC
# OK Eyssette LOC
# OK Quartier- LOC
# !!! Pas de localisation pour le LOC :  Charivaris
# OK Eyssette LOC
# OK Eyssette LOC
# OK È LOC
# OK Paris LOC
# OK Paris LOC
# OK Eu LOC
# OK Eu LOC
# OK l'Afrique LOC
# OK Paris LOC
# OK grésil LOC
# OK Champenoise LOC
# OK Paris LOC
# OK Champenoise LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK Quartier-Latin LOC
# OK Paris LOC
# OK Paris LOC
# OK Jardin des Plantes LOC
# OK Paris LOC
# OK Saint-Germain-des-Prés LOC
# OK clocher de Saint-Germain LOC
# OK Paris LOC
# OK Eyssette LOC
# OK Eu us ns LOC
# OK la Bretagne LOC
# OK rue Lanterne LOC
# OK Lyon LOC
# OK Annou LOC
# OK Lyon LOC
# OK du Nord LOC
# OK rue Lanterne LOC
# OK Lyon LOC
# OK Eyssette LOC
# OK Lyon LOC
# OK Paris LOC
# OK Paris LOC
# OK Saint-Nizier LOC
# OK faubourg Saint-Germain LOC
# OK Paris LOC
# OK Paris LOC
# OK Paris LOC
# OK faubourg Saint-Germain LOC
# OK rue de Lille LOC
# OK rue
#  LOC
# OK Saint-Guillaume LOC
# OK Saint-Nizier LOC
# !!! Pas de localisation pour le LOC :  m'’introduire
# OK Saint-Nizier LOC
# OK rue de Lille LOC
# OK BE LOC
# OK Saint-
# Nizier LOC
# OK rue Saint-Guillaume LOC
# OK Saint-Nizier LOC
# OK rue Saint-Guillaume LOC
# OK rue Saint-Guillaume LOC
# OK Saint-Nizier LOC
# OK Saint-Nizier LOC
# OK Saint-Nizier LOC
# OK Saint-Nizier LOC
# OK Saint-
# Nizier LOC
# OK Paris LOC
# OK rue Saint-Guillaume LOC
# OK rue de Lille LOC
# OK Hacqueville LOC
# OK Saint-Nizier LOC
# OK Paris LOC
# OK Hacqueville LOC
# OK Pérou LOC
# OK Hacqueville LOC
# OK Lx LOC
# OK Italie LOC
# OK Moustier LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Cévennes LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK mienne LOC
# OK Sarlande LOC
# OK Lyon LOC
# OK Hacqueville LOC
# OK clocher de Saint-Germain LOC
# OK Saint-Germain LOC
# OK Paris LOC
# OK Parisien LOC
# OK Paris LOC
# OK Saint-Germain-des-
# Prés LOC
# OK Rome LOC
# OK clocher de Saint-Germain LOC
# OK I LOC
# OK Parisien LOC
# OK Lyon LOC
# OK Paris LOC
# OK sur-le-champ LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Sapristi LOC
# !!! Pas de localisation pour le LOC :  Boucoyran
# OK Sarlande LOC
# OK la Prairie LOC
# OK Comédie-Française LOC
# OK Magnifique LOC
# OK F LOC
# OK Foin LOC
# OK pyramide d'Egypte LOC
# OK Palais-Mazarin LOC
# OK n'’irai LOC
# OK Saint- LOC
# OK rue Saint-Benoît LOC
# OK califourchon LOC
# OK Allons LOC
# OK È LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Tiens LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK Lyon LOC
# OK rue Lanterne LOC
# OK Saint-Germain LOC
# OK REP LOC
# OK Coucou-Blanc! LOC
# OK Saint-Germain-des-Prés LOC
# OK Daniel LOC
# OK Saint-Germain LOC
# OK ER LOC
# OK Saint-Germain LOC
# OK rue Saint-Benoît LOC
# OK Luxembourg LOC
# OK Pierrotte LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Musette LOC
# OK Nanterre LOC
# !!! Pas de localisation pour le LOC :  Tologototignan
# OK mans LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Cap LOC
# OK Coucou-
# Blanc LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  irons /à-bas
# OK Pierrotte LOC
# OK Palais-Royal LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Cévennes LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK RCE LOC
# OK Pierrotte LOC
# OK Eyssette LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Eyssette LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Cévennes LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Montmartre LOC
# !!! Pas de localisation pour le LOC :  Anastagille
# !!! Pas de localisation pour le LOC :  Anastagille
# !!! Pas de localisation pour le LOC :  Anastagille
# OK Pierrotte LOC
# OK Montmartre LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Parisiens LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Parisiens LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  mer
#
#
#
#
#
#
#
#
#
# LE ROMAN
# OK Languedoc LOC
# OK Pierrotte!
#
# Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Anastagille
# OK Pierrotte LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Bohême LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# OK Pierrotte LOC
# OK Saumon LOC
# OK Est LOC
# OK tournai LOC
# OK tournai LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK Pierrotte LOC
# OK Rosellen LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# !!! Pas de localisation pour le LOC :  Amalécites
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mile Coucou-Blanc
# OK Coucou-Blanc LOC
# OK Pierrotte LOC
# OK Coucou-Blanc LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK Allons LOC
# OK Pierrotte LOC
# OK Bach’ LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK clocher de Saint-Germain LOC
# OK Saumon LOC
# OK Porcelaines LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK Philistine LOC
# OK Pierrotte LOC
# OK clocher de Saint-Germain LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Est LOC
# !!! Pas de localisation pour le LOC :  Mile Coucou
# OK Coucou-Blanc LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK «Ce LOC
# !!! Pas de localisation pour le LOC :  Mile Pierrotte
# OK ner là-bas LOC
# OK tES
#
# EE LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Rosellen LOC
# OK cs LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Désir-de-plaire
# OK clocher de Saint-Germain LOC
# OK Jacques LOC
# OK bordeaux LOC
# !!! Pas de localisation pour le LOC :  Lakçamana
# !!! Pas de localisation pour le LOC :  Kalatçala
# OK Çudra LOC
# !!! Pas de localisation pour le LOC :  Cunocépa
# !!! Pas de localisation pour le LOC :  Viçva-
# OK mitra LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK École d’Alfort LOC
# OK Grand-Orient LOC
# OK Fougeroux LOC
# OK Pierrotte LOC
# OK Sar- LOC
# OK Pierrotte LOC
# OK I LOC
# OK le Muguet LOC
# OK Araignée LOC
# OK Suis LOC
# OK P LOC
# OK Muguets LOC
# OK Muguets LOC
# OK Muguets LOC
# OK Bas LOC
# OK Chardon LOC
# OK A LOC
# !!! Pas de localisation pour le LOC :  Nécro-
# OK cimetière des Papillons LOC
# OK VENDRAS LOC
# OK Caveau LOC
# OK Alfort LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Malheureuse- LOC
# OK Observatoire LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK PSS Sd
#
#
#
# LL LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Rosellen LOC
# OK Vénus LOC
# OK TIRER LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Ê LOC
# OK Alsacien LOC
# OK A LOC
# OK SRE LOC
# OK VENDRAS LOC
# OK clocher de Saint-Germain LOC
# OK Pierrotte LOC
# OK Odéon LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Saint-Benoît LOC
# OK Paris LOC
# OK Eyssette LOC
# OK Jardin des Plantes LOC
# OK fe LOC
# OK Théâtre-Français LOC
# !!! Pas de localisation pour le LOC :  huppe jaune
# OK îles Marquises LOC
# !!! Pas de localisation pour le LOC :  kakatoès
# OK Théâtre- LOC
# OK Français LOC
# OK îles Marquises LOC
# OK VENDRAS LOC
# OK Eyssette LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# OK Pierrotte LOC
# OK baie de Naples LOC
# OK Coucou-Blanc LOC
# OK Ebloui LOC
# OK Colombine LOC
# OK I LOC
# !!! Pas de localisation pour le LOC :  Saint-Pétesbourg
# OK Naples LOC
# OK îles Marquises LOC
# OK Port-au-Prince LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Théâtre-Français LOC
# OK Saumon LOC
# OK Porte LOC
# OK Tan LOC
# OK Saint-Germain LOC
# OK Nice LOC
# OK Hacqueville LOC
# OK Chili LOC
# OK victoria LOC
# OK Coucou-Blanc LOC
# OK Hacqueville LOC
# OK l'Italie LOC
# OK Rome LOC
# OK Naples LOC
# OK Pise LOC
# OK Palerme LOC
# !!! Pas de localisation pour le LOC :  Facques
# OK Eyssette LOC
# OK Pise LOC
# OK Cuba LOC
# OK Est LOC
# OK Est LOC
# OK Parthénon LOC
# !!! Pas de localisation pour le LOC :  mastoïdes
# OK Turc LOC
# OK Turc LOC
# OK Italien LOC
# OK tiennes LOC
# OK Turc LOC
# OK Est LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Porcelaines LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Prés-Saint-Gervais LOC
# OK Turc LOC
# OK théâtre de Paris LOC
# OK Éliacin LOC
# !!! Pas de localisation pour le LOC :  Consterna-
# OK ER LOC
# OK Gymnase LOC
# OK Théâtre-Français LOC
# OK Cuba LOC
# OK Coucou-Blanc LOC
# OK Turc LOC
# OK là-bas LOC
# OK Turc LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK boulevard Montparnasse LOC
# OK Coucou-Blanc LOC
# OK Rà LOC
# OK Coucou-Blanc LOC
# !!! Pas de localisation pour le LOC :  miséra-a-ble!
# OK Coucou-Blanc LOC
# OK titis LOC
# OK Grenelle LOC
# OK Mont- LOC
# OK Sèvres LOC
# OK Sceaux LOC
# OK Saint-Cloud LOC
# OK È LOC
# OK F LOC
# !!! Pas de localisation pour le LOC :  Souwaroff
# OK Lovelaces LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK Maine LOC
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK kohl LOC
# !!! Pas de localisation pour le LOC :  Langlumeau
# OK Pierrotte LOC
# OK théâtre Montparnasse LOC
# OK Rue des Dames LOC
# OK Batignolles LOC
# OK Paris LOC
# OK Palerme LOC
# OK Pierrotte LOC
# OK Paris LOC
# OK rue Bonaparte LOC
# OK Paris LOC
# OK Alsace LOC
# OK Regardez LOC
# OK Alsacien LOC
# OK Alsacien LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Chinois LOC
# OK Bohême LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  ENLÈVEMENT 219
#
# At
#
#
#
#
#
# Jacques
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Alsacien LOC
# OK Saint-Germain LOC
# OK Providence LOC
# OK Montparnasse LOC
# OK tour de Saint-Germain LOC
# OK Pilois LOC
# OK rue des Dames LOC
# OK Hacqueville LOC
# OK Marsala LOC
# OK des Batignolles LOC
# OK Mont- LOC
# OK Alsace LOC
# OK théâtre Montparnasse LOC
# !!! Pas de localisation pour le LOC :  Marie-feanne
# OK Luxembourg LOC
# OK mencé LOC
# !!! Pas de localisation pour le LOC :  Pilouitt!.
# OK Italiens LOC
# OK Paris LOC
# OK Pilois LOC
# OK Paris LOC
# OK clocher de Saint-Germain LOC
# OK Est LOC
# OK Est LOC
# OK sûmes LOC
# OK Pardieu LOC
# OK Paris LOC
# OK Allons LOC
# OK Ê LOC
# OK Pilois LOC
# OK Pierrotte LOC
# OK Montparnasse LOC
# OK Montparnasse LOC
# OK Est LOC
# OK Est LOC
# !!! Pas de localisation pour le LOC :  lamoelle de sos
# OK Coucou-Blanc LOC
# OK Coucou-Blanc LOC
# OK Pierrotte LOC
# OK Coucou-Blanc LOC
# OK Montmartre LOC
# OK Inde LOC
# OK Pilois LOC
# OK Lyon LOC
# OK Pilois LOC
# OK A LOC
# OK Pilois LOC
# OK Pilois!. LOC
# OK EE LOC
# OK Nice LOC
# OK Saint-Pierre LOC
# OK Sarlande LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Ià-bas LOC
# OK Paris LOC
# OK église Saint-Pierre LOC
# OK Montmartre LOC
# OK Paris LOC
# OK Midi LOC
# OK Pilois LOC
# OK Paris LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Montmartre LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Pb LOC
# !!! Pas de localisation pour le LOC :  Rime am
#
# EPS
#
# 244
# !!! Pas de localisation pour le LOC :  Pourvu
# OK là-bas LOC
# OK Pierrotte LOC
# OK Est LOC
# OK Est LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Saint-Emilion LOC
# !!! Pas de localisation pour le LOC :  om
#
# ru térmiétpe der
#
# En
#
# 246 LE PETIT
# OK Pierrotte LOC
# OK Montmartre LOC
# OK Providence LOC
# OK Eyssette LOC
# OK Pierrotte LOC
# !!! Pas de localisation pour le LOC :  Mie Pierrotte
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Montparnasse LOC
# OK Saumon LOC
# OK Pierrotte LOC
# OK Brûler LOC
# !!! Pas de localisation pour le LOC :  Madagas-
# OK Rana-Valo LOC
# OK Paris LOC
# OK Touraine LOC
# OK Chine LOC
# OK Pierrotte LOC
# OK Pierrotte LOC
# OK Eyssette LOC
